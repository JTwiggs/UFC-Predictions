# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Why do this step?
#
# - The data we scraped from the UFC website is raw data. Every row contains information about a fight that took place i.e. details like how many strikes were thrown in that fight and who won the fight.
# - To prepare the data for prediction, every row can contain only an accurate representation of what each fighter has done in fights up until that fight! No data that was recorded during the fight can be present in that row.
# - Our Target variable is Winner. The task has to be to predict the winner from the data available of each fighter up until the fight

# %% [markdown]
# ## Looking at the data

# %%
import pandas as pd
import numpy as np
import math

df = pd.read_csv('../data/raw_total_fight_data.csv', sep=';')
fighter_details = pd.read_csv('../data/raw_fighter_details.csv', index_col='fighter_name')

# %%
df.head()
# Out:
#         R_fighter           B_fighter  R_KD  B_KD R_SIG_STR. B_SIG_STR.  \
# 0  Justin Gaethje       Rafael Fiziev     1     0  72 of 134  68 of 119
# 1    Amanda Lemos      Iasmin Lucindo     0     0   12 of 21    4 of 16
# 2    Jalin Turner  Ignacio Bahamondes     0     0    7 of 20   10 of 16
# 3      Joshua Van         Rei Tsuruya     0     0   59 of 97   32 of 84
# 4    Alex Pereira    Magomed Ankalaev     0     0  76 of 137  94 of 180
#
#   R_SIG_STR_pct B_SIG_STR_pct R_TOTAL_STR. B_TOTAL_STR.  ... B_GROUND  \
# 0           53%           57%    98 of 163    81 of 134  ...   5 of 5
# 1           57%           25%     30 of 42     40 of 56  ...   1 of 1
# 2           35%           62%     11 of 25     17 of 23  ...   4 of 5
# 3           60%           38%   127 of 169    47 of 104  ...   0 of 0
# 4           55%           52%    97 of 159   127 of 224  ...   0 of 0
#
#                  win_by last_round last_round_time             Format  \
# 0  Decision - Unanimous          3            5:00      3 Rnd (5-5-5)
# 1  Decision - Unanimous          3            5:00      3 Rnd (5-5-5)
# 2            Submission          1            2:29      3 Rnd (5-5-5)
# 3  Decision - Unanimous          3            5:00      3 Rnd (5-5-5)
# 4  Decision - Unanimous          5            5:00  5 Rnd (5-5-5-5-5)
#
#           Referee            date                location  \
# 0    Jason Herzog  March 08, 2025  Las Vegas, Nevada, USA
# 1  Keith Peterson  March 08, 2025  Las Vegas, Nevada, USA
# 2      Mark Smith  March 08, 2025  Las Vegas, Nevada, USA
# 3    Jason Herzog  March 08, 2025  Las Vegas, Nevada, USA
# 4    Marc Goddard  March 08, 2025  Las Vegas, Nevada, USA
#
#                          Fight_type              Winner
# 0                  Lightweight Bout      Justin Gaethje
# 1          Women's Strawweight Bout        Amanda Lemos
# 2                  Lightweight Bout  Ignacio Bahamondes
# 3                    Flyweight Bout          Joshua Van
# 4  UFC Light Heavyweight Title Bout    Magomed Ankalaev
#
# [5 rows x 41 columns]

# %%
df.T
# Out:
#                                    0                         1     \
# R_fighter                Justin Gaethje              Amanda Lemos
# B_fighter                 Rafael Fiziev            Iasmin Lucindo
# R_KD                                  1                         0
# B_KD                                  0                         0
# R_SIG_STR.                    72 of 134                  12 of 21
# B_SIG_STR.                    68 of 119                   4 of 16
# R_SIG_STR_pct                       53%                       57%
# B_SIG_STR_pct                       57%                       25%
# R_TOTAL_STR.                  98 of 163                  30 of 42
# B_TOTAL_STR.                  81 of 134                  40 of 56
# R_TD                             0 of 3                    3 of 5
# B_TD                             2 of 2                    1 of 1
# R_TD_pct                             0%                       60%
# B_TD_pct                           100%                      100%
# R_SUB_ATT                             0                         0
# B_SUB_ATT                             0                         0
# R_REV                                 0                         0
# B_REV                                 0                         0
# R_CTRL                             1:32                      7:58
# B_CTRL                             0:40                      4:04
# R_HEAD                        56 of 117                   8 of 16
# B_HEAD                         20 of 61                   2 of 12
# R_BODY                           9 of 9                    2 of 3
# B_BODY                         43 of 52                    2 of 3
# R_LEG                            7 of 8                    2 of 2
# B_LEG                            5 of 6                    0 of 1
# R_DISTANCE                     41 of 92                   7 of 14
# B_DISTANCE                    49 of 100                   1 of 13
# R_CLINCH                       26 of 34                    1 of 1
# B_CLINCH                       14 of 14                    2 of 2
# R_GROUND                         5 of 8                    4 of 6
# B_GROUND                         5 of 5                    1 of 1
# win_by             Decision - Unanimous      Decision - Unanimous
# last_round                            3                         3
# last_round_time                    5:00                      5:00
# Format                    3 Rnd (5-5-5)             3 Rnd (5-5-5)
# Referee                    Jason Herzog            Keith Peterson
# date                     March 08, 2025            March 08, 2025
# location         Las Vegas, Nevada, USA    Las Vegas, Nevada, USA
# Fight_type             Lightweight Bout  Women's Strawweight Bout
# Winner                   Justin Gaethje              Amanda Lemos
#
#                                    2                       3     \
# R_fighter                  Jalin Turner              Joshua Van
# B_fighter            Ignacio Bahamondes             Rei Tsuruya
# R_KD                                  0                       0
# B_KD                                  0                       0
# R_SIG_STR.                      7 of 20                59 of 97
# B_SIG_STR.                     10 of 16                32 of 84
# R_SIG_STR_pct                       35%                     60%
# B_SIG_STR_pct                       62%                     38%
# R_TOTAL_STR.                   11 of 25              127 of 169
# B_TOTAL_STR.                   17 of 23               47 of 104
# R_TD                             0 of 0                  0 of 0
# B_TD                             0 of 1                 4 of 21
# R_TD_pct                            ---                     ---
# B_TD_pct                             0%                     19%
# R_SUB_ATT                             0                       0
# B_SUB_ATT                             1                       0
# R_REV                                 0                       0
# B_REV                                 0                       0
# R_CTRL                             1:43                    0:50
# B_CTRL                             0:00                    3:49
# R_HEAD                          4 of 16                39 of 74
# B_HEAD                          7 of 13                28 of 78
# R_BODY                           2 of 3                19 of 22
# B_BODY                           0 of 0                  2 of 4
# R_LEG                            1 of 1                  1 of 1
# B_LEG                            3 of 3                  2 of 2
# R_DISTANCE                      5 of 12                53 of 90
# B_DISTANCE                      6 of 11                32 of 83
# R_CLINCH                         0 of 1                  5 of 5
# B_CLINCH                         0 of 0                  0 of 1
# R_GROUND                         2 of 7                  1 of 2
# B_GROUND                         4 of 5                  0 of 0
# win_by                       Submission    Decision - Unanimous
# last_round                            1                       3
# last_round_time                    2:29                    5:00
# Format                    3 Rnd (5-5-5)           3 Rnd (5-5-5)
# Referee                      Mark Smith            Jason Herzog
# date                     March 08, 2025          March 08, 2025
# location         Las Vegas, Nevada, USA  Las Vegas, Nevada, USA
# Fight_type             Lightweight Bout          Flyweight Bout
# Winner               Ignacio Bahamondes              Joshua Van
#
#                                              4                       5     \
# R_fighter                            Alex Pereira              King Green
# B_fighter                        Magomed Ankalaev          Mauricio Ruffy
# R_KD                                            0                       0
# B_KD                                            0                       1
# R_SIG_STR.                              76 of 137                 4 of 15
# B_SIG_STR.                              94 of 180                  4 of 9
# R_SIG_STR_pct                                 55%                     26%
# B_SIG_STR_pct                                 52%                     44%
# R_TOTAL_STR.                            97 of 159                 4 of 15
# B_TOTAL_STR.                           127 of 224                  4 of 9
# R_TD                                       0 of 1                  0 of 0
# B_TD                                      0 of 12                  0 of 0
# R_TD_pct                                       0%                     ---
# B_TD_pct                                       0%                     ---
# R_SUB_ATT                                       0                       0
# B_SUB_ATT                                       0                       0
# R_REV                                           0                       0
# B_REV                                           0                       0
# R_CTRL                                       0:00                    0:00
# B_CTRL                                       5:42                    0:00
# R_HEAD                                   11 of 57                  1 of 7
# B_HEAD                                  36 of 112                  4 of 7
# R_BODY                                   17 of 25                  1 of 3
# B_BODY                                   30 of 39                  0 of 0
# R_LEG                                    48 of 55                  2 of 5
# B_LEG                                    28 of 29                  0 of 2
# R_DISTANCE                              69 of 130                 4 of 15
# B_DISTANCE                              75 of 159                  4 of 9
# R_CLINCH                                   7 of 7                  0 of 0
# B_CLINCH                                 19 of 21                  0 of 0
# R_GROUND                                   0 of 0                  0 of 0
# B_GROUND                                   0 of 0                  0 of 0
# win_by                       Decision - Unanimous                  KO/TKO
# last_round                                      5                       1
# last_round_time                              5:00                    2:07
# Format                          5 Rnd (5-5-5-5-5)           3 Rnd (5-5-5)
# Referee                              Marc Goddard           Chris Tognoni
# date                               March 08, 2025          March 08, 2025
# location                   Las Vegas, Nevada, USA  Las Vegas, Nevada, USA
# Fight_type       UFC Light Heavyweight Title Bout        Lightweight Bout
# Winner                           Magomed Ankalaev          Mauricio Ruffy
#
#                                    6                       7     \
# R_fighter               Brunno Ferreira             Alex Morono
# B_fighter               Armen Petrosyan             Carlos Leal
# R_KD                                  0                       0
# B_KD                                  0                       0
# R_SIG_STR.                     27 of 56                40 of 95
# B_SIG_STR.                     46 of 83               79 of 120
# R_SIG_STR_pct                       48%                     42%
# B_SIG_STR_pct                       55%                     65%
# R_TOTAL_STR.                   31 of 63                41 of 96
# B_TOTAL_STR.                   47 of 84               81 of 123
# R_TD                             2 of 7                  0 of 1
# B_TD                             0 of 0                  0 of 0
# R_TD_pct                            28%                      0%
# B_TD_pct                            ---                     ---
# R_SUB_ATT                             1                       0
# B_SUB_ATT                             0                       0
# R_REV                                 0                       0
# B_REV                                 0                       0
# R_CTRL                             1:12                    0:20
# B_CTRL                             0:00                    0:03
# R_HEAD                         14 of 40                32 of 82
# B_HEAD                         19 of 54                49 of 89
# R_BODY                          9 of 10                  4 of 9
# B_BODY                           7 of 7                28 of 29
# R_LEG                            4 of 6                  4 of 4
# B_LEG                          20 of 22                  2 of 2
# R_DISTANCE                     25 of 53                35 of 87
# B_DISTANCE                     46 of 83                54 of 91
# R_CLINCH                         2 of 3                  5 of 8
# B_CLINCH                         0 of 0                25 of 29
# R_GROUND                         0 of 0                  0 of 0
# B_GROUND                         0 of 0                  0 of 0
# win_by                       Submission                  KO/TKO
# last_round                            2                       1
# last_round_time                    4:27                    4:16
# Format                    3 Rnd (5-5-5)           3 Rnd (5-5-5)
# Referee                      Mark Smith          Keith Peterson
# date                     March 08, 2025          March 08, 2025
# location         Las Vegas, Nevada, USA  Las Vegas, Nevada, USA
# Fight_type            Middleweight Bout       Welterweight Bout
# Winner                  Brunno Ferreira             Carlos Leal
#
#                                    8                       9     ...  \
# R_fighter                Djorden Santos           Mairon Santos  ...
# B_fighter                     Ozzy Diaz        Francis Marshall  ...
# R_KD                                  0                       0  ...
# B_KD                                  0                       0  ...
# R_SIG_STR.                   131 of 345               58 of 129  ...
# B_SIG_STR.                   135 of 261               39 of 143  ...
# R_SIG_STR_pct                       37%                     44%  ...
# B_SIG_STR_pct                       51%                     27%  ...
# R_TOTAL_STR.                 134 of 348               78 of 154  ...
# B_TOTAL_STR.                 136 of 262               64 of 179  ...
# R_TD                             1 of 3                  0 of 1  ...
# B_TD                             0 of 0                  3 of 5  ...
# R_TD_pct                            33%                      0%  ...
# B_TD_pct                            ---                     60%  ...
# R_SUB_ATT                             0                       0  ...
# B_SUB_ATT                             0                       0  ...
# R_REV                                 0                       0  ...
# B_REV                                 0                       0  ...
# R_CTRL                             0:26                    0:02  ...
# B_CTRL                             0:00                    2:35  ...
# R_HEAD                       115 of 323                29 of 80  ...
# B_HEAD                       119 of 240               32 of 136  ...
# R_BODY                          8 of 14                14 of 30  ...
# B_BODY                          9 of 13                  1 of 1  ...
# R_LEG                            8 of 8                15 of 19  ...
# B_LEG                            7 of 8                  6 of 6  ...
# R_DISTANCE                   130 of 342               57 of 128  ...
# B_DISTANCE                   130 of 255               39 of 142  ...
# R_CLINCH                         0 of 1                  1 of 1  ...
# B_CLINCH                         5 of 6                  0 of 0  ...
# R_GROUND                         1 of 2                  0 of 0  ...
# B_GROUND                         0 of 0                  0 of 1  ...
# win_by             Decision - Unanimous        Decision - Split  ...
# last_round                            3                       3  ...
# last_round_time                    5:00                    5:00  ...
# Format                    3 Rnd (5-5-5)           3 Rnd (5-5-5)  ...
# Referee                    Marc Goddard           Chris Tognoni  ...
# date                     March 08, 2025          March 08, 2025  ...
# location         Las Vegas, Nevada, USA  Las Vegas, Nevada, USA  ...
# Fight_type            Middleweight Bout      Featherweight Bout  ...
# Winner                        Ozzy Diaz           Mairon Santos  ...
#
#                                   8037                   8038  \
# R_fighter                Patrick Smith           Royce Gracie
# B_fighter                 Scott Morris        Minoki Ichihara
# R_KD                                 0                      0
# B_KD                                 0                      0
# R_SIG_STR.                    13 of 17                 2 of 4
# B_SIG_STR.                      0 of 0                 3 of 7
# R_SIG_STR_pct                      76%                    50%
# B_SIG_STR_pct                      ---                    42%
# R_TOTAL_STR.                  19 of 25             110 of 114
# B_TOTAL_STR.                    0 of 0               12 of 16
# R_TD                            0 of 0                 1 of 1
# B_TD                            0 of 1                 0 of 0
# R_TD_pct                           ---                   100%
# B_TD_pct                            0%                    ---
# R_SUB_ATT                            0                      2
# B_SUB_ATT                            0                      0
# R_REV                                0                      0
# B_REV                                0                      0
# R_CTRL                              --                     --
# B_CTRL                              --                     --
# R_HEAD                        12 of 16                 0 of 0
# B_HEAD                          0 of 0                 3 of 6
# R_BODY                          1 of 1                 0 of 0
# B_BODY                          0 of 0                 0 of 0
# R_LEG                           0 of 0                 2 of 4
# B_LEG                           0 of 0                 0 of 1
# R_DISTANCE                      0 of 0                 2 of 4
# B_DISTANCE                      0 of 0                 0 of 2
# R_CLINCH                        1 of 1                 0 of 0
# B_CLINCH                        0 of 0                 0 of 0
# R_GROUND                      12 of 16                 0 of 0
# B_GROUND                        0 of 0                 3 of 5
# win_by                          KO/TKO             Submission
# last_round                           1                      1
# last_round_time                   0:30                   5:08
# Format                   No Time Limit          No Time Limit
# Referee                  John McCarthy          John McCarthy
# date                    March 11, 1994         March 11, 1994
# location         Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type            Open Weight Bout       Open Weight Bout
# Winner                   Patrick Smith           Royce Gracie
#
#                                   8039                   8040  \
# R_fighter                Johnny Rhodes          Jason DeLucia
# B_fighter                  Fred Ettish            Scott Baker
# R_KD                                 1                      0
# B_KD                                 0                      0
# R_SIG_STR.                    13 of 29                 3 of 5
# B_SIG_STR.                      4 of 7                 0 of 2
# R_SIG_STR_pct                      44%                    60%
# B_SIG_STR_pct                      57%                     0%
# R_TOTAL_STR.                  21 of 38               20 of 25
# B_TOTAL_STR.                   7 of 11               14 of 23
# R_TD                            0 of 0                 0 of 1
# B_TD                            0 of 0                 1 of 1
# R_TD_pct                           ---                     0%
# B_TD_pct                           ---                   100%
# R_SUB_ATT                            1                      5
# B_SUB_ATT                            0                      0
# R_REV                                0                      4
# B_REV                                0                      2
# R_CTRL                              --                     --
# B_CTRL                              --                     --
# R_HEAD                        12 of 28                 1 of 2
# B_HEAD                          0 of 1                 0 of 2
# R_BODY                          0 of 0                 1 of 2
# B_BODY                          2 of 4                 0 of 0
# R_LEG                           1 of 1                 1 of 1
# B_LEG                           2 of 2                 0 of 0
# R_DISTANCE                      3 of 6                 2 of 4
# B_DISTANCE                      4 of 7                 0 of 2
# R_CLINCH                        1 of 2                 0 of 0
# B_CLINCH                        0 of 0                 0 of 0
# R_GROUND                       9 of 21                 1 of 1
# B_GROUND                        0 of 0                 0 of 0
# win_by                      Submission             Submission
# last_round                           1                      1
# last_round_time                   3:07                   6:41
# Format                   No Time Limit          No Time Limit
# Referee                  John McCarthy          John McCarthy
# date                    March 11, 1994         March 11, 1994
# location         Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type            Open Weight Bout       Open Weight Bout
# Winner                   Johnny Rhodes          Jason DeLucia
#
#                                   8041                   8042  \
# R_fighter                Remco Pardoel           Orlando Wiet
# B_fighter           Alberta Cerra Leon       Robert Lucarelli
# R_KD                                 0                      0
# B_KD                                 0                      0
# R_SIG_STR.                      4 of 6                8 of 12
# B_SIG_STR.                      1 of 3                 2 of 6
# R_SIG_STR_pct                      66%                    66%
# B_SIG_STR_pct                      33%                    33%
# R_TOTAL_STR.                  20 of 22               11 of 15
# B_TOTAL_STR.                   9 of 11                 2 of 6
# R_TD                            1 of 1                 0 of 0
# B_TD                            0 of 0                 1 of 1
# R_TD_pct                          100%                    ---
# B_TD_pct                           ---                   100%
# R_SUB_ATT                            1                      0
# B_SUB_ATT                            0                      1
# R_REV                                0                      0
# B_REV                                0                      0
# R_CTRL                              --                     --
# B_CTRL                              --                     --
# R_HEAD                          4 of 5                7 of 11
# B_HEAD                          1 of 3                 1 of 2
# R_BODY                          0 of 0                 1 of 1
# B_BODY                          0 of 0                 0 of 1
# R_LEG                           0 of 1                 0 of 0
# B_LEG                           0 of 0                 1 of 3
# R_DISTANCE                      0 of 1                 1 of 3
# B_DISTANCE                      1 of 1                 2 of 6
# R_CLINCH                        0 of 0                 0 of 0
# B_CLINCH                        0 of 0                 0 of 0
# R_GROUND                        4 of 5                 7 of 9
# B_GROUND                        0 of 2                 0 of 0
# win_by                      Submission                 KO/TKO
# last_round                           1                      1
# last_round_time                   9:51                   2:50
# Format                   No Time Limit          No Time Limit
# Referee                  John McCarthy          John McCarthy
# date                    March 11, 1994         March 11, 1994
# location         Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type            Open Weight Bout       Open Weight Bout
# Winner                   Remco Pardoel           Orlando Wiet
#
#                                   8043                   8044  \
# R_fighter                Johnny Rhodes          Patrick Smith
# B_fighter                David Levicki             Ray Wizard
# R_KD                                 0                      0
# B_KD                                 0                      0
# R_SIG_STR.                    11 of 17                 1 of 1
# B_SIG_STR.                      4 of 5                 1 of 1
# R_SIG_STR_pct                      64%                   100%
# B_SIG_STR_pct                      80%                   100%
# R_TOTAL_STR.                  74 of 86                 1 of 1
# B_TOTAL_STR.                 95 of 102                 2 of 2
# R_TD                            1 of 1                 0 of 1
# B_TD                            0 of 0                 0 of 0
# R_TD_pct                          100%                     0%
# B_TD_pct                           ---                    ---
# R_SUB_ATT                            0                      1
# B_SUB_ATT                            0                      0
# R_REV                                0                      0
# B_REV                                0                      0
# R_CTRL                              --                     --
# B_CTRL                              --                     --
# R_HEAD                         9 of 15                 0 of 0
# B_HEAD                          4 of 5                 0 of 0
# R_BODY                          1 of 1                 1 of 1
# B_BODY                          0 of 0                 0 of 0
# R_LEG                           1 of 1                 0 of 0
# B_LEG                           0 of 0                 1 of 1
# R_DISTANCE                      1 of 1                 0 of 0
# B_DISTANCE                      1 of 2                 1 of 1
# R_CLINCH                        1 of 1                 1 of 1
# B_CLINCH                        2 of 2                 0 of 0
# R_GROUND                       9 of 15                 0 of 0
# B_GROUND                        1 of 1                 0 of 0
# win_by                          KO/TKO             Submission
# last_round                           1                      1
# last_round_time                  12:13                   0:58
# Format                   No Time Limit          No Time Limit
# Referee                  John McCarthy          John McCarthy
# date                    March 11, 1994         March 11, 1994
# location         Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type            Open Weight Bout       Open Weight Bout
# Winner                   Johnny Rhodes          Patrick Smith
#
#                                   8045                   8046
# R_fighter                Frank Hamaker           Scott Morris
# B_fighter              Thaddeus Luster         Sean Daugherty
# R_KD                                 0                      0
# B_KD                                 0                      0
# R_SIG_STR.                      2 of 3                 1 of 1
# B_SIG_STR.                      0 of 0                 0 of 4
# R_SIG_STR_pct                      66%                   100%
# B_SIG_STR_pct                      ---                     0%
# R_TOTAL_STR.                  14 of 15                 2 of 2
# B_TOTAL_STR.                    0 of 0                 1 of 5
# R_TD                            1 of 1                 1 of 1
# B_TD                            0 of 1                 0 of 0
# R_TD_pct                          100%                   100%
# B_TD_pct                            0%                    ---
# R_SUB_ATT                            3                      1
# B_SUB_ATT                            0                      0
# R_REV                                1                      0
# B_REV                                0                      0
# R_CTRL                              --                     --
# B_CTRL                              --                     --
# R_HEAD                          2 of 3                 1 of 1
# B_HEAD                          0 of 0                 0 of 2
# R_BODY                          0 of 0                 0 of 0
# B_BODY                          0 of 0                 0 of 0
# R_LEG                           0 of 0                 0 of 0
# B_LEG                           0 of 0                 0 of 2
# R_DISTANCE                      1 of 1                 0 of 0
# B_DISTANCE                      0 of 0                 0 of 3
# R_CLINCH                        0 of 0                 1 of 1
# B_CLINCH                        0 of 0                 0 of 1
# R_GROUND                        1 of 2                 0 of 0
# B_GROUND                        0 of 0                 0 of 0
# win_by                      Submission             Submission
# last_round                           1                      1
# last_round_time                   4:52                   0:20
# Format                   No Time Limit          No Time Limit
# Referee                  John McCarthy          John McCarthy
# date                    March 11, 1994         March 11, 1994
# location         Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type            Open Weight Bout       Open Weight Bout
# Winner                   Frank Hamaker           Scott Morris
#
# [41 rows x 8047 columns]

# %%
df.describe()
# Out:
#               R_KD         B_KD    R_SUB_ATT    B_SUB_ATT        R_REV  \
# count  8047.000000  8047.000000  8047.000000  8047.000000  8047.000000
# mean      0.244812     0.181186     0.443271     0.321362     0.136697
# std       0.517374     0.457467     0.883737     0.753561     0.429122
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     1.000000     0.000000     0.000000
# max       5.000000     4.000000    10.000000     7.000000     6.000000
#
#              B_REV   last_round
# count  8047.000000  8047.000000
# mean      0.134709     2.354294
# std       0.421280     1.016084
# min       0.000000     1.000000
# 25%       0.000000     1.000000
# 50%       0.000000     3.000000
# 75%       0.000000     3.000000
# max       5.000000     5.000000

# %%
df.dtypes
# Out:
# R_fighter          object
# B_fighter          object
# R_KD                int64
# B_KD                int64
# R_SIG_STR.         object
# B_SIG_STR.         object
# R_SIG_STR_pct      object
# B_SIG_STR_pct      object
# R_TOTAL_STR.       object
# B_TOTAL_STR.       object
# R_TD               object
# B_TD               object
# R_TD_pct           object
# B_TD_pct           object
# R_SUB_ATT           int64
# B_SUB_ATT           int64
# R_REV               int64
# B_REV               int64
# R_CTRL             object
# B_CTRL             object
# R_HEAD             object
# B_HEAD             object
# R_BODY             object
# B_BODY             object
# R_LEG              object
# B_LEG              object
# R_DISTANCE         object
# B_DISTANCE         object
# R_CLINCH           object
# B_CLINCH           object
# R_GROUND           object
# B_GROUND           object
# win_by             object
# last_round          int64
# last_round_time    object
# Format             object
# Referee            object
# date               object
# location           object
# Fight_type         object
# Winner             object
# dtype: object

# %%
df.columns
# Out:
# Index(['R_fighter', 'B_fighter', 'R_KD', 'B_KD', 'R_SIG_STR.', 'B_SIG_STR.',
#        'R_SIG_STR_pct', 'B_SIG_STR_pct', 'R_TOTAL_STR.', 'B_TOTAL_STR.',
#        'R_TD', 'B_TD', 'R_TD_pct', 'B_TD_pct', 'R_SUB_ATT', 'B_SUB_ATT',
#        'R_REV', 'B_REV', 'R_CTRL', 'B_CTRL', 'R_HEAD', 'B_HEAD', 'R_BODY',
#        'B_BODY', 'R_LEG', 'B_LEG', 'R_DISTANCE', 'B_DISTANCE', 'R_CLINCH',
#        'B_CLINCH', 'R_GROUND', 'B_GROUND', 'win_by', 'last_round',
#        'last_round_time', 'Format', 'Referee', 'date', 'location',
#        'Fight_type', 'Winner'],
#       dtype='object')

# %% [markdown]
# ### Column definitions:
#
# - `R_` and `B_` prefix signifies red and blue corner fighter stats respectively
# - `KD` is number of knockdowns
# - `SIG_STR` is no. of significant strikes 'landed of attempted'
# - `SIG_STR_pct` is significant strikes percentage
# - `TOTAL_STR` is total strikes 'landed of attempted'
# - `TD` is no. of takedowns
# - `TD_pct` is takedown percentages
# - `SUB_ATT` is no. of submission attempts
# - `PASS` is no. times the guard was passed?
# - `REV` is the no. of reversals
# - `CTRL` is the time spent with ground control
# - `HEAD` is no. of significant strinks to the head 'landed of attempted'
# - `BODY` is no. of significant strikes to the body 'landed of attempted'
# - `CLINCH` is no. of significant strikes in the clinch 'landed of attempted'
# - `GROUND` is no. of significant strikes on the ground 'landed of attempted'
# - `win_by` is method of win
# - `last_round` is last round of the fight (ex. if it was a KO in 1st, then this will be 1)
# - `last_round_time` is when the fight ended in the last round
# - `Format` is the format of the fight (3 rounds, 5 rounds etc.)
# - `Referee` is the name of the Ref
# - `date` is the date of the fight
# - `location` is the location in which the event took place
# - `Fight_type` is which weight class and whether it's a title bout or not
# - `Winner` is the winner of the fight
#
# #### Per fighter career wide stats
# - `SLpM` - Significant Strikes Landed per Minute
# - `Str_Acc.` - Significant Striking Accuracy
# - `SApM` - Significant Strikes Absorbed per Minute
# - `Str_Def` - Significant Strike Defence (the % of opponents strikes that did not land)
# - `TD_Avg` - Average Takedowns Landed per 15 minutes
# - `TD_Acc` - Takedown Accuracy
# - `TD_Def` - Takedown Defense (the % of opponents TD attempts that did not land)
# - `Sub_Avg` - Average Submissions Attempted per 15 minutes

# %% [markdown]
# ## Todo:
#
# - Separate `landed of attempted` to separate columns
#
# - Convert `Fight_type` into two separate columns, `weight_class` and `Title_fight` (True or False)
#
# - Convert `last_round_time` to `total_time_fought` by using `last_round` and `Format`
#
# - Convert `CTRL` to `time_in_CTRL`
#
# - Convert percentages to fractions
#
# - Since the data is a description of each fight, we have to convert it into a format that shows the compilation data of each fighter up until that fight. This means every row will look a lot different than it looks now.
#
# - Create `current_win_streak`, `current_lose_streak`, `longest_win_streak`, `wins`, `losses`, `draw`
#
# - Create fighter `height`, `reach`, `weight`, `age`

# %%
fighter_details.drop(
    columns=["SLpM",
            "Str_Acc",
            "SApM",
            "Str_Def",
            "TD_Avg",
            "TD_Acc",
            "TD_Def",
            "Sub_Avg",
        ], inplace=True)

# %% [markdown]
# ### Splitting landed of attempted to different columns

# %%
columns = ['R_SIG_STR.', 'B_SIG_STR.', 'R_TOTAL_STR.', 'B_TOTAL_STR.',
       'R_TD', 'B_TD', 'R_HEAD', 'B_HEAD', 'R_BODY','B_BODY', 'R_LEG', 'B_LEG', 
        'R_DISTANCE', 'B_DISTANCE', 'R_CLINCH','B_CLINCH', 'R_GROUND', 'B_GROUND']

for column in columns:
    print(f"{column} data type is: {df[column].dtype}")
# Out:
# R_SIG_STR. data type is: object
# B_SIG_STR. data type is: object
# R_TOTAL_STR. data type is: object
# B_TOTAL_STR. data type is: object
# R_TD data type is: object
# B_TD data type is: object
# R_HEAD data type is: object
# B_HEAD data type is: object
# R_BODY data type is: object
# B_BODY data type is: object
# R_LEG data type is: object
# B_LEG data type is: object
# R_DISTANCE data type is: object
# B_DISTANCE data type is: object
# R_CLINCH data type is: object
# B_CLINCH data type is: object
# R_GROUND data type is: object
# B_GROUND data type is: object

# %%
attempt_suffix = '_att'
landed_suffix = '_landed'

for column in columns:
    df[column+attempt_suffix] = df[column].apply(lambda X: int(X.split('of')[1]))
    df[column+landed_suffix] = df[column].apply(lambda X: int(X.split('of')[0]))
    
df.drop(columns, axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['R_fighter', 'B_fighter', 'R_KD', 'B_KD', 'R_SIG_STR_pct',
#        'B_SIG_STR_pct', 'R_TD_pct', 'B_TD_pct', 'R_SUB_ATT', 'B_SUB_ATT',
#        'R_REV', 'B_REV', 'R_CTRL', 'B_CTRL', 'win_by', 'last_round',
#        'last_round_time', 'Format', 'Referee', 'date', 'location',
#        'Fight_type', 'Winner', 'R_SIG_STR._att', 'R_SIG_STR._landed',
#        'B_SIG_STR._att', 'B_SIG_STR._landed', 'R_TOTAL_STR._att',
#        'R_TOTAL_STR._landed', 'B_TOTAL_STR._att', 'B_TOTAL_STR._landed',
#        'R_TD_att', 'R_TD_landed', 'B_TD_att', 'B_TD_landed', 'R_HEAD_att',
#        'R_HEAD_landed', 'B_HEAD_att', 'B_HEAD_landed', 'R_BODY_att',
#        'R_BODY_landed', 'B_BODY_att', 'B_BODY_landed', 'R_LEG_att',
#        'R_LEG_landed', 'B_LEG_att', 'B_LEG_landed', 'R_DISTANCE_att',
#        'R_DISTANCE_landed', 'B_DISTANCE_att', 'B_DISTANCE_landed',
#        'R_CLINCH_att', 'R_CLINCH_landed', 'B_CLINCH_att', 'B_CLINCH_landed',
#        'R_GROUND_att', 'R_GROUND_landed', 'B_GROUND_att', 'B_GROUND_landed'],
#       dtype='object')

# %% [markdown]
# ### Replacing Winner NaNs as Draw

# %%
for column in df.columns:
    if df[column].isnull().sum() != 0:
        print(f"NaN values in {column} = {df[column].isnull().sum()}")
# Out:
# NaN values in Referee = 26
# NaN values in Winner = 145

# %% [markdown]
# * 83 missing values in winner and 23 missing values in Referee

# %%
df[df['Winner'].isnull()]['win_by'].value_counts()
# Out:
# win_by
# Overturned              57
# Decision - Majority     34
# Could Not Continue      29
# Decision - Split        17
# Decision - Unanimous     6
# Other                    2
# Name: count, dtype: int64

# %% [markdown]
# * Here, Overturned means due to drug test being positive and Could not Continue means there was an illegal blow which was not enough to be disqualified but the fighter could not continue.
# * The rest are different forms of draw
#
# * Replacing all of these with draw

# %%
# df['Winner'].fillna('Draw', inplace=True)
df.fillna({'Winner': 'Draw'}, inplace=True)

# %% [markdown]
# ### Converting percentages to fractions

# %%
pct_columns = ['R_SIG_STR_pct','B_SIG_STR_pct', 'R_TD_pct', 'B_TD_pct']

def pct_to_frac(X):
    if X != '---':
        return float(X.replace('%', ''))/100
    else:
        # if '---' means it's taking pct of `0 of 0`. 
        # Taking a call here to consider 0 landed of 0 attempted as 0 percentage
        return 0

for column in pct_columns:
    df[column] = df[column].apply(pct_to_frac)

# %%
df.T
# Out:
#                                        0                         1     \
# R_fighter                    Justin Gaethje              Amanda Lemos
# B_fighter                     Rafael Fiziev            Iasmin Lucindo
# R_KD                                      1                         0
# B_KD                                      0                         0
# R_SIG_STR_pct                          0.53                      0.57
# B_SIG_STR_pct                          0.57                      0.25
# R_TD_pct                                0.0                       0.6
# B_TD_pct                                1.0                       1.0
# R_SUB_ATT                                 0                         0
# B_SUB_ATT                                 0                         0
# R_REV                                     0                         0
# B_REV                                     0                         0
# R_CTRL                                 1:32                      7:58
# B_CTRL                                 0:40                      4:04
# win_by                 Decision - Unanimous      Decision - Unanimous
# last_round                                3                         3
# last_round_time                        5:00                      5:00
# Format                        3 Rnd (5-5-5)             3 Rnd (5-5-5)
# Referee                        Jason Herzog            Keith Peterson
# date                         March 08, 2025            March 08, 2025
# location             Las Vegas, Nevada, USA    Las Vegas, Nevada, USA
# Fight_type                 Lightweight Bout  Women's Strawweight Bout
# Winner                       Justin Gaethje              Amanda Lemos
# R_SIG_STR._att                          134                        21
# R_SIG_STR._landed                        72                        12
# B_SIG_STR._att                          119                        16
# B_SIG_STR._landed                        68                         4
# R_TOTAL_STR._att                        163                        42
# R_TOTAL_STR._landed                      98                        30
# B_TOTAL_STR._att                        134                        56
# B_TOTAL_STR._landed                      81                        40
# R_TD_att                                  3                         5
# R_TD_landed                               0                         3
# B_TD_att                                  2                         1
# B_TD_landed                               2                         1
# R_HEAD_att                              117                        16
# R_HEAD_landed                            56                         8
# B_HEAD_att                               61                        12
# B_HEAD_landed                            20                         2
# R_BODY_att                                9                         3
# R_BODY_landed                             9                         2
# B_BODY_att                               52                         3
# B_BODY_landed                            43                         2
# R_LEG_att                                 8                         2
# R_LEG_landed                              7                         2
# B_LEG_att                                 6                         1
# B_LEG_landed                              5                         0
# R_DISTANCE_att                           92                        14
# R_DISTANCE_landed                        41                         7
# B_DISTANCE_att                          100                        13
# B_DISTANCE_landed                        49                         1
# R_CLINCH_att                             34                         1
# R_CLINCH_landed                          26                         1
# B_CLINCH_att                             14                         2
# B_CLINCH_landed                          14                         2
# R_GROUND_att                              8                         6
# R_GROUND_landed                           5                         4
# B_GROUND_att                              5                         1
# B_GROUND_landed                           5                         1
#
#                                        2                       3     \
# R_fighter                      Jalin Turner              Joshua Van
# B_fighter                Ignacio Bahamondes             Rei Tsuruya
# R_KD                                      0                       0
# B_KD                                      0                       0
# R_SIG_STR_pct                          0.35                     0.6
# B_SIG_STR_pct                          0.62                    0.38
# R_TD_pct                                0.0                     0.0
# B_TD_pct                                0.0                    0.19
# R_SUB_ATT                                 0                       0
# B_SUB_ATT                                 1                       0
# R_REV                                     0                       0
# B_REV                                     0                       0
# R_CTRL                                 1:43                    0:50
# B_CTRL                                 0:00                    3:49
# win_by                           Submission    Decision - Unanimous
# last_round                                1                       3
# last_round_time                        2:29                    5:00
# Format                        3 Rnd (5-5-5)           3 Rnd (5-5-5)
# Referee                          Mark Smith            Jason Herzog
# date                         March 08, 2025          March 08, 2025
# location             Las Vegas, Nevada, USA  Las Vegas, Nevada, USA
# Fight_type                 Lightweight Bout          Flyweight Bout
# Winner                   Ignacio Bahamondes              Joshua Van
# R_SIG_STR._att                           20                      97
# R_SIG_STR._landed                         7                      59
# B_SIG_STR._att                           16                      84
# B_SIG_STR._landed                        10                      32
# R_TOTAL_STR._att                         25                     169
# R_TOTAL_STR._landed                      11                     127
# B_TOTAL_STR._att                         23                     104
# B_TOTAL_STR._landed                      17                      47
# R_TD_att                                  0                       0
# R_TD_landed                               0                       0
# B_TD_att                                  1                      21
# B_TD_landed                               0                       4
# R_HEAD_att                               16                      74
# R_HEAD_landed                             4                      39
# B_HEAD_att                               13                      78
# B_HEAD_landed                             7                      28
# R_BODY_att                                3                      22
# R_BODY_landed                             2                      19
# B_BODY_att                                0                       4
# B_BODY_landed                             0                       2
# R_LEG_att                                 1                       1
# R_LEG_landed                              1                       1
# B_LEG_att                                 3                       2
# B_LEG_landed                              3                       2
# R_DISTANCE_att                           12                      90
# R_DISTANCE_landed                         5                      53
# B_DISTANCE_att                           11                      83
# B_DISTANCE_landed                         6                      32
# R_CLINCH_att                              1                       5
# R_CLINCH_landed                           0                       5
# B_CLINCH_att                              0                       1
# B_CLINCH_landed                           0                       0
# R_GROUND_att                              7                       2
# R_GROUND_landed                           2                       1
# B_GROUND_att                              5                       0
# B_GROUND_landed                           4                       0
#
#                                                  4                       5     \
# R_fighter                                Alex Pereira              King Green
# B_fighter                            Magomed Ankalaev          Mauricio Ruffy
# R_KD                                                0                       0
# B_KD                                                0                       1
# R_SIG_STR_pct                                    0.55                    0.26
# B_SIG_STR_pct                                    0.52                    0.44
# R_TD_pct                                          0.0                     0.0
# B_TD_pct                                          0.0                     0.0
# R_SUB_ATT                                           0                       0
# B_SUB_ATT                                           0                       0
# R_REV                                               0                       0
# B_REV                                               0                       0
# R_CTRL                                           0:00                    0:00
# B_CTRL                                           5:42                    0:00
# win_by                           Decision - Unanimous                  KO/TKO
# last_round                                          5                       1
# last_round_time                                  5:00                    2:07
# Format                              5 Rnd (5-5-5-5-5)           3 Rnd (5-5-5)
# Referee                                  Marc Goddard           Chris Tognoni
# date                                   March 08, 2025          March 08, 2025
# location                       Las Vegas, Nevada, USA  Las Vegas, Nevada, USA
# Fight_type           UFC Light Heavyweight Title Bout        Lightweight Bout
# Winner                               Magomed Ankalaev          Mauricio Ruffy
# R_SIG_STR._att                                    137                      15
# R_SIG_STR._landed                                  76                       4
# B_SIG_STR._att                                    180                       9
# B_SIG_STR._landed                                  94                       4
# R_TOTAL_STR._att                                  159                      15
# R_TOTAL_STR._landed                                97                       4
# B_TOTAL_STR._att                                  224                       9
# B_TOTAL_STR._landed                               127                       4
# R_TD_att                                            1                       0
# R_TD_landed                                         0                       0
# B_TD_att                                           12                       0
# B_TD_landed                                         0                       0
# R_HEAD_att                                         57                       7
# R_HEAD_landed                                      11                       1
# B_HEAD_att                                        112                       7
# B_HEAD_landed                                      36                       4
# R_BODY_att                                         25                       3
# R_BODY_landed                                      17                       1
# B_BODY_att                                         39                       0
# B_BODY_landed                                      30                       0
# R_LEG_att                                          55                       5
# R_LEG_landed                                       48                       2
# B_LEG_att                                          29                       2
# B_LEG_landed                                       28                       0
# R_DISTANCE_att                                    130                      15
# R_DISTANCE_landed                                  69                       4
# B_DISTANCE_att                                    159                       9
# B_DISTANCE_landed                                  75                       4
# R_CLINCH_att                                        7                       0
# R_CLINCH_landed                                     7                       0
# B_CLINCH_att                                       21                       0
# B_CLINCH_landed                                    19                       0
# R_GROUND_att                                        0                       0
# R_GROUND_landed                                     0                       0
# B_GROUND_att                                        0                       0
# B_GROUND_landed                                     0                       0
#
#                                        6                       7     \
# R_fighter                   Brunno Ferreira             Alex Morono
# B_fighter                   Armen Petrosyan             Carlos Leal
# R_KD                                      0                       0
# B_KD                                      0                       0
# R_SIG_STR_pct                          0.48                    0.42
# B_SIG_STR_pct                          0.55                    0.65
# R_TD_pct                               0.28                     0.0
# B_TD_pct                                0.0                     0.0
# R_SUB_ATT                                 1                       0
# B_SUB_ATT                                 0                       0
# R_REV                                     0                       0
# B_REV                                     0                       0
# R_CTRL                                 1:12                    0:20
# B_CTRL                                 0:00                    0:03
# win_by                           Submission                  KO/TKO
# last_round                                2                       1
# last_round_time                        4:27                    4:16
# Format                        3 Rnd (5-5-5)           3 Rnd (5-5-5)
# Referee                          Mark Smith          Keith Peterson
# date                         March 08, 2025          March 08, 2025
# location             Las Vegas, Nevada, USA  Las Vegas, Nevada, USA
# Fight_type                Middleweight Bout       Welterweight Bout
# Winner                      Brunno Ferreira             Carlos Leal
# R_SIG_STR._att                           56                      95
# R_SIG_STR._landed                        27                      40
# B_SIG_STR._att                           83                     120
# B_SIG_STR._landed                        46                      79
# R_TOTAL_STR._att                         63                      96
# R_TOTAL_STR._landed                      31                      41
# B_TOTAL_STR._att                         84                     123
# B_TOTAL_STR._landed                      47                      81
# R_TD_att                                  7                       1
# R_TD_landed                               2                       0
# B_TD_att                                  0                       0
# B_TD_landed                               0                       0
# R_HEAD_att                               40                      82
# R_HEAD_landed                            14                      32
# B_HEAD_att                               54                      89
# B_HEAD_landed                            19                      49
# R_BODY_att                               10                       9
# R_BODY_landed                             9                       4
# B_BODY_att                                7                      29
# B_BODY_landed                             7                      28
# R_LEG_att                                 6                       4
# R_LEG_landed                              4                       4
# B_LEG_att                                22                       2
# B_LEG_landed                             20                       2
# R_DISTANCE_att                           53                      87
# R_DISTANCE_landed                        25                      35
# B_DISTANCE_att                           83                      91
# B_DISTANCE_landed                        46                      54
# R_CLINCH_att                              3                       8
# R_CLINCH_landed                           2                       5
# B_CLINCH_att                              0                      29
# B_CLINCH_landed                           0                      25
# R_GROUND_att                              0                       0
# R_GROUND_landed                           0                       0
# B_GROUND_att                              0                       0
# B_GROUND_landed                           0                       0
#
#                                        8                       9     ...  \
# R_fighter                    Djorden Santos           Mairon Santos  ...
# B_fighter                         Ozzy Diaz        Francis Marshall  ...
# R_KD                                      0                       0  ...
# B_KD                                      0                       0  ...
# R_SIG_STR_pct                          0.37                    0.44  ...
# B_SIG_STR_pct                          0.51                    0.27  ...
# R_TD_pct                               0.33                     0.0  ...
# B_TD_pct                                0.0                     0.6  ...
# R_SUB_ATT                                 0                       0  ...
# B_SUB_ATT                                 0                       0  ...
# R_REV                                     0                       0  ...
# B_REV                                     0                       0  ...
# R_CTRL                                 0:26                    0:02  ...
# B_CTRL                                 0:00                    2:35  ...
# win_by                 Decision - Unanimous        Decision - Split  ...
# last_round                                3                       3  ...
# last_round_time                        5:00                    5:00  ...
# Format                        3 Rnd (5-5-5)           3 Rnd (5-5-5)  ...
# Referee                        Marc Goddard           Chris Tognoni  ...
# date                         March 08, 2025          March 08, 2025  ...
# location             Las Vegas, Nevada, USA  Las Vegas, Nevada, USA  ...
# Fight_type                Middleweight Bout      Featherweight Bout  ...
# Winner                            Ozzy Diaz           Mairon Santos  ...
# R_SIG_STR._att                          345                     129  ...
# R_SIG_STR._landed                       131                      58  ...
# B_SIG_STR._att                          261                     143  ...
# B_SIG_STR._landed                       135                      39  ...
# R_TOTAL_STR._att                        348                     154  ...
# R_TOTAL_STR._landed                     134                      78  ...
# B_TOTAL_STR._att                        262                     179  ...
# B_TOTAL_STR._landed                     136                      64  ...
# R_TD_att                                  3                       1  ...
# R_TD_landed                               1                       0  ...
# B_TD_att                                  0                       5  ...
# B_TD_landed                               0                       3  ...
# R_HEAD_att                              323                      80  ...
# R_HEAD_landed                           115                      29  ...
# B_HEAD_att                              240                     136  ...
# B_HEAD_landed                           119                      32  ...
# R_BODY_att                               14                      30  ...
# R_BODY_landed                             8                      14  ...
# B_BODY_att                               13                       1  ...
# B_BODY_landed                             9                       1  ...
# R_LEG_att                                 8                      19  ...
# R_LEG_landed                              8                      15  ...
# B_LEG_att                                 8                       6  ...
# B_LEG_landed                              7                       6  ...
# R_DISTANCE_att                          342                     128  ...
# R_DISTANCE_landed                       130                      57  ...
# B_DISTANCE_att                          255                     142  ...
# B_DISTANCE_landed                       130                      39  ...
# R_CLINCH_att                              1                       1  ...
# R_CLINCH_landed                           0                       1  ...
# B_CLINCH_att                              6                       0  ...
# B_CLINCH_landed                           5                       0  ...
# R_GROUND_att                              2                       0  ...
# R_GROUND_landed                           1                       0  ...
# B_GROUND_att                              0                       1  ...
# B_GROUND_landed                           0                       0  ...
#
#                                       8037                   8038  \
# R_fighter                    Patrick Smith           Royce Gracie
# B_fighter                     Scott Morris        Minoki Ichihara
# R_KD                                     0                      0
# B_KD                                     0                      0
# R_SIG_STR_pct                         0.76                    0.5
# B_SIG_STR_pct                          0.0                   0.42
# R_TD_pct                               0.0                    1.0
# B_TD_pct                               0.0                    0.0
# R_SUB_ATT                                0                      2
# B_SUB_ATT                                0                      0
# R_REV                                    0                      0
# B_REV                                    0                      0
# R_CTRL                                  --                     --
# B_CTRL                                  --                     --
# win_by                              KO/TKO             Submission
# last_round                               1                      1
# last_round_time                       0:30                   5:08
# Format                       No Time Limit          No Time Limit
# Referee                      John McCarthy          John McCarthy
# date                        March 11, 1994         March 11, 1994
# location             Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type                Open Weight Bout       Open Weight Bout
# Winner                       Patrick Smith           Royce Gracie
# R_SIG_STR._att                          17                      4
# R_SIG_STR._landed                       13                      2
# B_SIG_STR._att                           0                      7
# B_SIG_STR._landed                        0                      3
# R_TOTAL_STR._att                        25                    114
# R_TOTAL_STR._landed                     19                    110
# B_TOTAL_STR._att                         0                     16
# B_TOTAL_STR._landed                      0                     12
# R_TD_att                                 0                      1
# R_TD_landed                              0                      1
# B_TD_att                                 1                      0
# B_TD_landed                              0                      0
# R_HEAD_att                              16                      0
# R_HEAD_landed                           12                      0
# B_HEAD_att                               0                      6
# B_HEAD_landed                            0                      3
# R_BODY_att                               1                      0
# R_BODY_landed                            1                      0
# B_BODY_att                               0                      0
# B_BODY_landed                            0                      0
# R_LEG_att                                0                      4
# R_LEG_landed                             0                      2
# B_LEG_att                                0                      1
# B_LEG_landed                             0                      0
# R_DISTANCE_att                           0                      4
# R_DISTANCE_landed                        0                      2
# B_DISTANCE_att                           0                      2
# B_DISTANCE_landed                        0                      0
# R_CLINCH_att                             1                      0
# R_CLINCH_landed                          1                      0
# B_CLINCH_att                             0                      0
# B_CLINCH_landed                          0                      0
# R_GROUND_att                            16                      0
# R_GROUND_landed                         12                      0
# B_GROUND_att                             0                      5
# B_GROUND_landed                          0                      3
#
#                                       8039                   8040  \
# R_fighter                    Johnny Rhodes          Jason DeLucia
# B_fighter                      Fred Ettish            Scott Baker
# R_KD                                     1                      0
# B_KD                                     0                      0
# R_SIG_STR_pct                         0.44                    0.6
# B_SIG_STR_pct                         0.57                    0.0
# R_TD_pct                               0.0                    0.0
# B_TD_pct                               0.0                    1.0
# R_SUB_ATT                                1                      5
# B_SUB_ATT                                0                      0
# R_REV                                    0                      4
# B_REV                                    0                      2
# R_CTRL                                  --                     --
# B_CTRL                                  --                     --
# win_by                          Submission             Submission
# last_round                               1                      1
# last_round_time                       3:07                   6:41
# Format                       No Time Limit          No Time Limit
# Referee                      John McCarthy          John McCarthy
# date                        March 11, 1994         March 11, 1994
# location             Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type                Open Weight Bout       Open Weight Bout
# Winner                       Johnny Rhodes          Jason DeLucia
# R_SIG_STR._att                          29                      5
# R_SIG_STR._landed                       13                      3
# B_SIG_STR._att                           7                      2
# B_SIG_STR._landed                        4                      0
# R_TOTAL_STR._att                        38                     25
# R_TOTAL_STR._landed                     21                     20
# B_TOTAL_STR._att                        11                     23
# B_TOTAL_STR._landed                      7                     14
# R_TD_att                                 0                      1
# R_TD_landed                              0                      0
# B_TD_att                                 0                      1
# B_TD_landed                              0                      1
# R_HEAD_att                              28                      2
# R_HEAD_landed                           12                      1
# B_HEAD_att                               1                      2
# B_HEAD_landed                            0                      0
# R_BODY_att                               0                      2
# R_BODY_landed                            0                      1
# B_BODY_att                               4                      0
# B_BODY_landed                            2                      0
# R_LEG_att                                1                      1
# R_LEG_landed                             1                      1
# B_LEG_att                                2                      0
# B_LEG_landed                             2                      0
# R_DISTANCE_att                           6                      4
# R_DISTANCE_landed                        3                      2
# B_DISTANCE_att                           7                      2
# B_DISTANCE_landed                        4                      0
# R_CLINCH_att                             2                      0
# R_CLINCH_landed                          1                      0
# B_CLINCH_att                             0                      0
# B_CLINCH_landed                          0                      0
# R_GROUND_att                            21                      1
# R_GROUND_landed                          9                      1
# B_GROUND_att                             0                      0
# B_GROUND_landed                          0                      0
#
#                                       8041                   8042  \
# R_fighter                    Remco Pardoel           Orlando Wiet
# B_fighter               Alberta Cerra Leon       Robert Lucarelli
# R_KD                                     0                      0
# B_KD                                     0                      0
# R_SIG_STR_pct                         0.66                   0.66
# B_SIG_STR_pct                         0.33                   0.33
# R_TD_pct                               1.0                    0.0
# B_TD_pct                               0.0                    1.0
# R_SUB_ATT                                1                      0
# B_SUB_ATT                                0                      1
# R_REV                                    0                      0
# B_REV                                    0                      0
# R_CTRL                                  --                     --
# B_CTRL                                  --                     --
# win_by                          Submission                 KO/TKO
# last_round                               1                      1
# last_round_time                       9:51                   2:50
# Format                       No Time Limit          No Time Limit
# Referee                      John McCarthy          John McCarthy
# date                        March 11, 1994         March 11, 1994
# location             Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type                Open Weight Bout       Open Weight Bout
# Winner                       Remco Pardoel           Orlando Wiet
# R_SIG_STR._att                           6                     12
# R_SIG_STR._landed                        4                      8
# B_SIG_STR._att                           3                      6
# B_SIG_STR._landed                        1                      2
# R_TOTAL_STR._att                        22                     15
# R_TOTAL_STR._landed                     20                     11
# B_TOTAL_STR._att                        11                      6
# B_TOTAL_STR._landed                      9                      2
# R_TD_att                                 1                      0
# R_TD_landed                              1                      0
# B_TD_att                                 0                      1
# B_TD_landed                              0                      1
# R_HEAD_att                               5                     11
# R_HEAD_landed                            4                      7
# B_HEAD_att                               3                      2
# B_HEAD_landed                            1                      1
# R_BODY_att                               0                      1
# R_BODY_landed                            0                      1
# B_BODY_att                               0                      1
# B_BODY_landed                            0                      0
# R_LEG_att                                1                      0
# R_LEG_landed                             0                      0
# B_LEG_att                                0                      3
# B_LEG_landed                             0                      1
# R_DISTANCE_att                           1                      3
# R_DISTANCE_landed                        0                      1
# B_DISTANCE_att                           1                      6
# B_DISTANCE_landed                        1                      2
# R_CLINCH_att                             0                      0
# R_CLINCH_landed                          0                      0
# B_CLINCH_att                             0                      0
# B_CLINCH_landed                          0                      0
# R_GROUND_att                             5                      9
# R_GROUND_landed                          4                      7
# B_GROUND_att                             2                      0
# B_GROUND_landed                          0                      0
#
#                                       8043                   8044  \
# R_fighter                    Johnny Rhodes          Patrick Smith
# B_fighter                    David Levicki             Ray Wizard
# R_KD                                     0                      0
# B_KD                                     0                      0
# R_SIG_STR_pct                         0.64                    1.0
# B_SIG_STR_pct                          0.8                    1.0
# R_TD_pct                               1.0                    0.0
# B_TD_pct                               0.0                    0.0
# R_SUB_ATT                                0                      1
# B_SUB_ATT                                0                      0
# R_REV                                    0                      0
# B_REV                                    0                      0
# R_CTRL                                  --                     --
# B_CTRL                                  --                     --
# win_by                              KO/TKO             Submission
# last_round                               1                      1
# last_round_time                      12:13                   0:58
# Format                       No Time Limit          No Time Limit
# Referee                      John McCarthy          John McCarthy
# date                        March 11, 1994         March 11, 1994
# location             Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type                Open Weight Bout       Open Weight Bout
# Winner                       Johnny Rhodes          Patrick Smith
# R_SIG_STR._att                          17                      1
# R_SIG_STR._landed                       11                      1
# B_SIG_STR._att                           5                      1
# B_SIG_STR._landed                        4                      1
# R_TOTAL_STR._att                        86                      1
# R_TOTAL_STR._landed                     74                      1
# B_TOTAL_STR._att                       102                      2
# B_TOTAL_STR._landed                     95                      2
# R_TD_att                                 1                      1
# R_TD_landed                              1                      0
# B_TD_att                                 0                      0
# B_TD_landed                              0                      0
# R_HEAD_att                              15                      0
# R_HEAD_landed                            9                      0
# B_HEAD_att                               5                      0
# B_HEAD_landed                            4                      0
# R_BODY_att                               1                      1
# R_BODY_landed                            1                      1
# B_BODY_att                               0                      0
# B_BODY_landed                            0                      0
# R_LEG_att                                1                      0
# R_LEG_landed                             1                      0
# B_LEG_att                                0                      1
# B_LEG_landed                             0                      1
# R_DISTANCE_att                           1                      0
# R_DISTANCE_landed                        1                      0
# B_DISTANCE_att                           2                      1
# B_DISTANCE_landed                        1                      1
# R_CLINCH_att                             1                      1
# R_CLINCH_landed                          1                      1
# B_CLINCH_att                             2                      0
# B_CLINCH_landed                          2                      0
# R_GROUND_att                            15                      0
# R_GROUND_landed                          9                      0
# B_GROUND_att                             1                      0
# B_GROUND_landed                          1                      0
#
#                                       8045                   8046
# R_fighter                    Frank Hamaker           Scott Morris
# B_fighter                  Thaddeus Luster         Sean Daugherty
# R_KD                                     0                      0
# B_KD                                     0                      0
# R_SIG_STR_pct                         0.66                    1.0
# B_SIG_STR_pct                          0.0                    0.0
# R_TD_pct                               1.0                    1.0
# B_TD_pct                               0.0                    0.0
# R_SUB_ATT                                3                      1
# B_SUB_ATT                                0                      0
# R_REV                                    1                      0
# B_REV                                    0                      0
# R_CTRL                                  --                     --
# B_CTRL                                  --                     --
# win_by                          Submission             Submission
# last_round                               1                      1
# last_round_time                       4:52                   0:20
# Format                       No Time Limit          No Time Limit
# Referee                      John McCarthy          John McCarthy
# date                        March 11, 1994         March 11, 1994
# location             Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type                Open Weight Bout       Open Weight Bout
# Winner                       Frank Hamaker           Scott Morris
# R_SIG_STR._att                           3                      1
# R_SIG_STR._landed                        2                      1
# B_SIG_STR._att                           0                      4
# B_SIG_STR._landed                        0                      0
# R_TOTAL_STR._att                        15                      2
# R_TOTAL_STR._landed                     14                      2
# B_TOTAL_STR._att                         0                      5
# B_TOTAL_STR._landed                      0                      1
# R_TD_att                                 1                      1
# R_TD_landed                              1                      1
# B_TD_att                                 1                      0
# B_TD_landed                              0                      0
# R_HEAD_att                               3                      1
# R_HEAD_landed                            2                      1
# B_HEAD_att                               0                      2
# B_HEAD_landed                            0                      0
# R_BODY_att                               0                      0
# R_BODY_landed                            0                      0
# B_BODY_att                               0                      0
# B_BODY_landed                            0                      0
# R_LEG_att                                0                      0
# R_LEG_landed                             0                      0
# B_LEG_att                                0                      2
# B_LEG_landed                             0                      0
# R_DISTANCE_att                           1                      0
# R_DISTANCE_landed                        1                      0
# B_DISTANCE_att                           0                      3
# B_DISTANCE_landed                        0                      0
# R_CLINCH_att                             0                      1
# R_CLINCH_landed                          0                      1
# B_CLINCH_att                             0                      1
# B_CLINCH_landed                          0                      0
# R_GROUND_att                             2                      0
# R_GROUND_landed                          1                      0
# B_GROUND_att                             0                      0
# B_GROUND_landed                          0                      0
#
# [59 rows x 8047 columns]

# %% [markdown]
# ### Creating a title_bout feature and weight_class

# %%
df['Fight_type'].value_counts()
# Out:
# Fight_type
# Lightweight Bout               1315
# Welterweight Bout              1262
# Middleweight Bout              1009
# Featherweight Bout              757
# Bantamweight Bout               678
#                                ...
# UFC 6 Tournament Title Bout       1
# UFC 5 Tournament Title Bout       1
# UFC 4 Tournament Title Bout       1
# UFC 3 Tournament Title Bout       1
# UFC 2 Tournament Title Bout       1
# Name: count, Length: 113, dtype: int64

# %%
df['Fight_type'].value_counts()[df['Fight_type'].value_counts() > 1].index
# Out:
# Index(['Lightweight Bout', 'Welterweight Bout', 'Middleweight Bout',
#        'Featherweight Bout', 'Bantamweight Bout', 'Heavyweight Bout',
#        'Light Heavyweight Bout', 'Flyweight Bout', 'Women's Strawweight Bout',
#        'Women's Flyweight Bout', 'Women's Bantamweight Bout',
#        'Open Weight Bout', 'Catch Weight Bout',
#        'UFC Light Heavyweight Title Bout', 'UFC Welterweight Title Bout',
#        'UFC Heavyweight Title Bout', 'UFC Middleweight Title Bout',
#        'UFC Lightweight Title Bout', 'UFC Flyweight Title Bout',
#        'UFC Bantamweight Title Bout', 'Women's Featherweight Bout',
#        'UFC Featherweight Title Bout', 'UFC Women's Strawweight Title Bout',
#        'UFC Women's Bantamweight Title Bout',
#        'UFC Women's Flyweight Title Bout',
#        'UFC Interim Heavyweight Title Bout',
#        'UFC Women's Featherweight Title Bout',
#        'UFC Superfight Championship Bout',
#        'UFC Interim Featherweight Title Bout',
#        'UFC Interim Bantamweight Title Bout',
#        'UFC Interim Lightweight Title Bout',
#        'UFC Interim Welterweight Title Bout',
#        'UFC Interim Middleweight Title Bout',
#        'UFC Interim Light Heavyweight Title Bout'],
#       dtype='object', name='Fight_type')

# %%
df['title_bout'] = df['Fight_type'].apply(lambda X: True if 'Title Bout' in X else False)

# %%
def make_weight_class(X):
    for weight_class in weight_classes:
        if weight_class in X:
            return weight_class
    if X == 'Catch Weight Bout' or 'Catchweight Bout':
        return 'Catch Weight'
    else:
        return 'Open Weight'

# %%
weight_classes = ['Women\'s Strawweight', 'Women\'s Bantamweight', 
                  'Women\'s Featherweight', 'Women\'s Flyweight', 'Lightweight', 
                  'Welterweight', 'Middleweight','Light Heavyweight', 
                  'Heavyweight', 'Featherweight','Bantamweight', 'Flyweight', 'Open Weight']

df['weight_class'] = df['Fight_type'].apply(make_weight_class)

# %%
df[df['weight_class'].isnull()]['Fight_type'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# ### Creating total_time_fought

# %%
df['Format'].value_counts()
# Out:
# Format
# 3 Rnd (5-5-5)           7100
# 5 Rnd (5-5-5-5-5)        715
# 1 Rnd + OT (12-3)         80
# 3 Rnd + OT (5-5-5-5)      38
# No Time Limit             29
# 1 Rnd (20)                21
# 1 Rnd + 2OT (15-3-3)      20
# 2 Rnd (5-5)               14
# 1 Rnd (15)                 8
# 1 Rnd (10)                 6
# 1 Rnd (12)                 4
# 1 Rnd + OT (30-5)          3
# 1 Rnd + OT (15-3)          2
# 1 Rnd (18)                 2
# 1 Rnd + 2OT (24-3-3)       1
# 1 Rnd + OT (27-3)          1
# 1 Rnd + OT (30-3)          1
# 1 Rnd (30)                 1
# 1 Rnd + OT (31-5)          1
# Name: count, dtype: int64

# %%
df['Format'].value_counts().index
# Out:
# Index(['3 Rnd (5-5-5)', '5 Rnd (5-5-5-5-5)', '1 Rnd + OT (12-3)',
#        '3 Rnd + OT (5-5-5-5)', 'No Time Limit', '1 Rnd (20)',
#        '1 Rnd + 2OT (15-3-3)', '2 Rnd (5-5)', '1 Rnd (15)', '1 Rnd (10)',
#        '1 Rnd (12)', '1 Rnd + OT (30-5)', '1 Rnd + OT (15-3)', '1 Rnd (18)',
#        '1 Rnd + 2OT (24-3-3)', '1 Rnd + OT (27-3)', '1 Rnd + OT (30-3)',
#        '1 Rnd (30)', '1 Rnd + OT (31-5)'],
#       dtype='object', name='Format')

# %%
time_in_first_round = {'3 Rnd (5-5-5)': 5*60, '5 Rnd (5-5-5-5-5)': 5*60, '1 Rnd + OT (12-3)': 12*60,
       'No Time Limit': 1, '3 Rnd + OT (5-5-5-5)': 5*60, '1 Rnd (20)': 1*20,
       '2 Rnd (5-5)': 5*60, '1 Rnd (15)': 15*60, '1 Rnd (10)': 10*60,
       '1 Rnd (12)':12*60, '1 Rnd + OT (30-5)': 30*60, '1 Rnd (18)': 18*60, '1 Rnd + OT (15-3)': 15*60,
       '1 Rnd (30)': 30*60, '1 Rnd + OT (31-5)': 31*5,
       '1 Rnd + OT (27-3)': 27*60, '1 Rnd + OT (30-3)': 30*60}

exception_format_time = {'1 Rnd + 2OT (15-3-3)': [15*60, 3*60], '1 Rnd + 2OT (24-3-3)': [24*60, 3*60]}

# '1 Rnd + 2OT (15-3-3)' and '1 Rnd + 2OT (24-3-3)' is not included because it has 3 uneven timed rounds. 
# We'll have to deal with it separately

# %%
# Converting to seconds
df['last_round_time'] = df['last_round_time'].apply(lambda X: int(X.split(':')[0])*60 + int(X.split(':')[1]))

# %%
def get_total_time(row):
    if row['Format'] in time_in_first_round.keys():
        return (row['last_round'] - 1) * time_in_first_round[row['Format']] + row['last_round_time']
    elif row['Format'] in exception_format_time.keys():
        if (row['last_round'] - 1) >= 2:
            return exception_format_time[row['Format']][0] + (row['last_round'] - 2) * \
                    exception_format_time[row['Format']][1] + row['last_round_time']
        else:
            return (row['last_round'] - 1) * exception_format_time[row['Format']][0] + row['last_round_time']
    
# So if the fight ended in round 1, we only need last_round_time. 
# If it ended in round 2, we need the full time of round 1 and the last_round_time
# This works for fights with same time in each round and fights with only two rounds.

# %%
df['total_time_fought(seconds)'] = df.apply(get_total_time, axis=1)

# %%
def get_no_of_rounds(X):
    if X == 'No Time Limit':
        return 1
    else:
        return len(X.split('(')[1].replace(')', '').split('-'))

df['no_of_rounds'] = df['Format'].apply(get_no_of_rounds)

# %%
df
# Out:
#            R_fighter           B_fighter  R_KD  B_KD  R_SIG_STR_pct  \
# 0     Justin Gaethje       Rafael Fiziev     1     0           0.53
# 1       Amanda Lemos      Iasmin Lucindo     0     0           0.57
# 2       Jalin Turner  Ignacio Bahamondes     0     0           0.35
# 3         Joshua Van         Rei Tsuruya     0     0           0.60
# 4       Alex Pereira    Magomed Ankalaev     0     0           0.55
# ...              ...                 ...   ...   ...            ...
# 8042    Orlando Wiet    Robert Lucarelli     0     0           0.66
# 8043   Johnny Rhodes       David Levicki     0     0           0.64
# 8044   Patrick Smith          Ray Wizard     0     0           1.00
# 8045   Frank Hamaker     Thaddeus Luster     0     0           0.66
# 8046    Scott Morris      Sean Daugherty     0     0           1.00
#
#       B_SIG_STR_pct  R_TD_pct  B_TD_pct  R_SUB_ATT  B_SUB_ATT  ...  \
# 0              0.57       0.0      1.00          0          0  ...
# 1              0.25       0.6      1.00          0          0  ...
# 2              0.62       0.0      0.00          0          1  ...
# 3              0.38       0.0      0.19          0          0  ...
# 4              0.52       0.0      0.00          0          0  ...
# ...             ...       ...       ...        ...        ...  ...
# 8042           0.33       0.0      1.00          0          1  ...
# 8043           0.80       1.0      0.00          0          0  ...
# 8044           1.00       0.0      0.00          1          0  ...
# 8045           0.00       1.0      0.00          3          0  ...
# 8046           0.00       1.0      0.00          1          0  ...
#
#       B_CLINCH_att  B_CLINCH_landed R_GROUND_att R_GROUND_landed B_GROUND_att  \
# 0               14               14            8               5            5
# 1                2                2            6               4            1
# 2                0                0            7               2            5
# 3                1                0            2               1            0
# 4               21               19            0               0            0
# ...            ...              ...          ...             ...          ...
# 8042             0                0            9               7            0
# 8043             2                2           15               9            1
# 8044             0                0            0               0            0
# 8045             0                0            2               1            0
# 8046             1                0            0               0            0
#
#       B_GROUND_landed  title_bout         weight_class  \
# 0                   5       False          Lightweight
# 1                   1       False  Women's Strawweight
# 2                   4       False          Lightweight
# 3                   0       False            Flyweight
# 4                   0        True    Light Heavyweight
# ...               ...         ...                  ...
# 8042                0       False          Open Weight
# 8043                1       False          Open Weight
# 8044                0       False          Open Weight
# 8045                0       False          Open Weight
# 8046                0       False          Open Weight
#
#      total_time_fought(seconds) no_of_rounds
# 0                           900            3
# 1                           900            3
# 2                           149            3
# 3                           900            3
# 4                          1500            5
# ...                         ...          ...
# 8042                        170            1
# 8043                        733            1
# 8044                         58            1
# 8045                        292            1
# 8046                         20            1
#
# [8047 rows x 63 columns]

# %%
df.drop(['Format', 'Fight_type', 'last_round_time'], axis = 1, inplace=True)

# %% [markdown]
# ### Create CTRL_time(seconds)

# %%
CTRL_columns = ['R_CTRL','B_CTRL']

def conv_to_sec(X):
    if X != '--':
        return int(X.split(':')[0])*60 + int(X.split(':')[1])
    else:
        # if '--' means there was no time spent on the ground. 
        # Taking a call here to consider this as 0 seconds
        return 0

for column in CTRL_columns:
    df[column+'_time(seconds)'] = df[column].apply(conv_to_sec)

# %%
df.T
# Out:
#                                       0                    1     \
# R_fighter                   Justin Gaethje         Amanda Lemos
# B_fighter                    Rafael Fiziev       Iasmin Lucindo
# R_KD                                     1                    0
# B_KD                                     0                    0
# R_SIG_STR_pct                         0.53                 0.57
# ...                                    ...                  ...
# weight_class                   Lightweight  Women's Strawweight
# total_time_fought(seconds)             900                  900
# no_of_rounds                             3                    3
# R_CTRL_time(seconds)                    92                  478
# B_CTRL_time(seconds)                    40                  244
#
#                                           2            3     \
# R_fighter                         Jalin Turner   Joshua Van
# B_fighter                   Ignacio Bahamondes  Rei Tsuruya
# R_KD                                         0            0
# B_KD                                         0            0
# R_SIG_STR_pct                             0.35          0.6
# ...                                        ...          ...
# weight_class                       Lightweight    Flyweight
# total_time_fought(seconds)                 149          900
# no_of_rounds                                 3            3
# R_CTRL_time(seconds)                       103           50
# B_CTRL_time(seconds)                         0          229
#
#                                          4               5     \
# R_fighter                        Alex Pereira      King Green
# B_fighter                    Magomed Ankalaev  Mauricio Ruffy
# R_KD                                        0               0
# B_KD                                        0               1
# R_SIG_STR_pct                            0.55            0.26
# ...                                       ...             ...
# weight_class                Light Heavyweight     Lightweight
# total_time_fought(seconds)               1500             127
# no_of_rounds                                5               3
# R_CTRL_time(seconds)                        0               0
# B_CTRL_time(seconds)                      342               0
#
#                                        6             7               8     \
# R_fighter                   Brunno Ferreira   Alex Morono  Djorden Santos
# B_fighter                   Armen Petrosyan   Carlos Leal       Ozzy Diaz
# R_KD                                      0             0               0
# B_KD                                      0             0               0
# R_SIG_STR_pct                          0.48          0.42            0.37
# ...                                     ...           ...             ...
# weight_class                   Middleweight  Welterweight    Middleweight
# total_time_fought(seconds)              567           256             900
# no_of_rounds                              3             3               3
# R_CTRL_time(seconds)                     72            20              26
# B_CTRL_time(seconds)                      0             3               0
#
#                                         9     ...           8037  \
# R_fighter                      Mairon Santos  ...  Patrick Smith
# B_fighter                   Francis Marshall  ...   Scott Morris
# R_KD                                       0  ...              0
# B_KD                                       0  ...              0
# R_SIG_STR_pct                           0.44  ...           0.76
# ...                                      ...  ...            ...
# weight_class                   Featherweight  ...    Open Weight
# total_time_fought(seconds)               900  ...             30
# no_of_rounds                               3  ...              1
# R_CTRL_time(seconds)                       2  ...              0
# B_CTRL_time(seconds)                     155  ...              0
#
#                                        8038           8039           8040  \
# R_fighter                      Royce Gracie  Johnny Rhodes  Jason DeLucia
# B_fighter                   Minoki Ichihara    Fred Ettish    Scott Baker
# R_KD                                      0              1              0
# B_KD                                      0              0              0
# R_SIG_STR_pct                           0.5           0.44            0.6
# ...                                     ...            ...            ...
# weight_class                    Open Weight    Open Weight    Open Weight
# total_time_fought(seconds)              308            187            401
# no_of_rounds                              1              1              1
# R_CTRL_time(seconds)                      0              0              0
# B_CTRL_time(seconds)                      0              0              0
#
#                                           8041              8042  \
# R_fighter                        Remco Pardoel      Orlando Wiet
# B_fighter                   Alberta Cerra Leon  Robert Lucarelli
# R_KD                                         0                 0
# B_KD                                         0                 0
# R_SIG_STR_pct                             0.66              0.66
# ...                                        ...               ...
# weight_class                       Open Weight       Open Weight
# total_time_fought(seconds)                 591               170
# no_of_rounds                                 1                 1
# R_CTRL_time(seconds)                         0                 0
# B_CTRL_time(seconds)                         0                 0
#
#                                      8043           8044             8045  \
# R_fighter                   Johnny Rhodes  Patrick Smith    Frank Hamaker
# B_fighter                   David Levicki     Ray Wizard  Thaddeus Luster
# R_KD                                    0              0                0
# B_KD                                    0              0                0
# R_SIG_STR_pct                        0.64            1.0             0.66
# ...                                   ...            ...              ...
# weight_class                  Open Weight    Open Weight      Open Weight
# total_time_fought(seconds)            733             58              292
# no_of_rounds                            1              1                1
# R_CTRL_time(seconds)                    0              0                0
# B_CTRL_time(seconds)                    0              0                0
#
#                                       8046
# R_fighter                     Scott Morris
# B_fighter                   Sean Daugherty
# R_KD                                     0
# B_KD                                     0
# R_SIG_STR_pct                          1.0
# ...                                    ...
# weight_class                   Open Weight
# total_time_fought(seconds)              20
# no_of_rounds                             1
# R_CTRL_time(seconds)                     0
# B_CTRL_time(seconds)                     0
#
# [62 rows x 8047 columns]

# %%
df.drop(['R_CTRL','B_CTRL'], axis = 1, inplace=True)

# %% [markdown]
# ### Create another DataFrame to save the compiled data per fighter (Our Prediction DataFrame)

# %%
df.columns
# Out:
# Index(['R_fighter', 'B_fighter', 'R_KD', 'B_KD', 'R_SIG_STR_pct',
#        'B_SIG_STR_pct', 'R_TD_pct', 'B_TD_pct', 'R_SUB_ATT', 'B_SUB_ATT',
#        'R_REV', 'B_REV', 'win_by', 'last_round', 'Referee', 'date', 'location',
#        'Winner', 'R_SIG_STR._att', 'R_SIG_STR._landed', 'B_SIG_STR._att',
#        'B_SIG_STR._landed', 'R_TOTAL_STR._att', 'R_TOTAL_STR._landed',
#        'B_TOTAL_STR._att', 'B_TOTAL_STR._landed', 'R_TD_att', 'R_TD_landed',
#        'B_TD_att', 'B_TD_landed', 'R_HEAD_att', 'R_HEAD_landed', 'B_HEAD_att',
#        'B_HEAD_landed', 'R_BODY_att', 'R_BODY_landed', 'B_BODY_att',
#        'B_BODY_landed', 'R_LEG_att', 'R_LEG_landed', 'B_LEG_att',
#        'B_LEG_landed', 'R_DISTANCE_att', 'R_DISTANCE_landed', 'B_DISTANCE_att',
#        'B_DISTANCE_landed', 'R_CLINCH_att', 'R_CLINCH_landed', 'B_CLINCH_att',
#        'B_CLINCH_landed', 'R_GROUND_att', 'R_GROUND_landed', 'B_GROUND_att',
#        'B_GROUND_landed', 'title_bout', 'weight_class',
#        'total_time_fought(seconds)', 'no_of_rounds', 'R_CTRL_time(seconds)',
#        'B_CTRL_time(seconds)'],
#       dtype='object')

# %%
df2 = df.copy()

# %%
df2.drop(['R_KD', 'B_KD', 'R_SIG_STR_pct',
       'B_SIG_STR_pct', 'R_TD_pct', 'B_TD_pct', 'R_SUB_ATT', 'B_SUB_ATT',
       'R_CTRL_time(seconds)', 'B_CTRL_time(seconds)', 'R_REV', 'B_REV', 'win_by', 'last_round', 
        'R_SIG_STR._att', 'R_SIG_STR._landed',
       'B_SIG_STR._att', 'B_SIG_STR._landed', 'R_TOTAL_STR._att',
       'R_TOTAL_STR._landed', 'B_TOTAL_STR._att', 'B_TOTAL_STR._landed',
       'R_TD_att', 'R_TD_landed', 'B_TD_att', 'B_TD_landed', 'R_HEAD_att',
       'R_HEAD_landed', 'B_HEAD_att', 'B_HEAD_landed', 'R_BODY_att',
       'R_BODY_landed', 'B_BODY_att', 'B_BODY_landed', 'R_LEG_att',
       'R_LEG_landed', 'B_LEG_att', 'B_LEG_landed', 'R_DISTANCE_att',
       'R_DISTANCE_landed', 'B_DISTANCE_att', 'B_DISTANCE_landed',
       'R_CLINCH_att', 'R_CLINCH_landed', 'B_CLINCH_att', 'B_CLINCH_landed',
       'R_GROUND_att', 'R_GROUND_landed', 'B_GROUND_att', 'B_GROUND_landed',
        'total_time_fought(seconds)'], axis = 1, inplace=True)
df2
# Out:
#            R_fighter           B_fighter         Referee            date  \
# 0     Justin Gaethje       Rafael Fiziev    Jason Herzog  March 08, 2025
# 1       Amanda Lemos      Iasmin Lucindo  Keith Peterson  March 08, 2025
# 2       Jalin Turner  Ignacio Bahamondes      Mark Smith  March 08, 2025
# 3         Joshua Van         Rei Tsuruya    Jason Herzog  March 08, 2025
# 4       Alex Pereira    Magomed Ankalaev    Marc Goddard  March 08, 2025
# ...              ...                 ...             ...             ...
# 8042    Orlando Wiet    Robert Lucarelli   John McCarthy  March 11, 1994
# 8043   Johnny Rhodes       David Levicki   John McCarthy  March 11, 1994
# 8044   Patrick Smith          Ray Wizard   John McCarthy  March 11, 1994
# 8045   Frank Hamaker     Thaddeus Luster   John McCarthy  March 11, 1994
# 8046    Scott Morris      Sean Daugherty   John McCarthy  March 11, 1994
#
#                     location              Winner  title_bout  \
# 0     Las Vegas, Nevada, USA      Justin Gaethje       False
# 1     Las Vegas, Nevada, USA        Amanda Lemos       False
# 2     Las Vegas, Nevada, USA  Ignacio Bahamondes       False
# 3     Las Vegas, Nevada, USA          Joshua Van       False
# 4     Las Vegas, Nevada, USA    Magomed Ankalaev        True
# ...                      ...                 ...         ...
# 8042   Denver, Colorado, USA        Orlando Wiet       False
# 8043   Denver, Colorado, USA       Johnny Rhodes       False
# 8044   Denver, Colorado, USA       Patrick Smith       False
# 8045   Denver, Colorado, USA       Frank Hamaker       False
# 8046   Denver, Colorado, USA        Scott Morris       False
#
#              weight_class  no_of_rounds
# 0             Lightweight             3
# 1     Women's Strawweight             3
# 2             Lightweight             3
# 3               Flyweight             3
# 4       Light Heavyweight             5
# ...                   ...           ...
# 8042          Open Weight             1
# 8043          Open Weight             1
# 8044          Open Weight             1
# 8045          Open Weight             1
# 8046          Open Weight             1
#
# [8047 rows x 9 columns]

# %% [markdown]
# ### Compiling Data per fighter

# %%
red_fighters = df['R_fighter'].value_counts().index
blue_fighters = df['B_fighter'].value_counts().index

fighters = list(set(red_fighters) | set(blue_fighters))

# %%
def get_renamed_winner(row):
    if row['R_fighter'] == row['Winner']:
        return 'Red'
    elif row['B_fighter'] == row['Winner']:
        return 'Blue'
    elif row['Winner'] == 'Draw':
        return 'Draw'

df2['Winner'] = df2[['R_fighter', 'B_fighter', 'Winner']].apply(get_renamed_winner, axis=1)

# %%
df = pd.concat([df,pd.get_dummies(df['win_by'], prefix='win_by')],axis=1)
df.drop(['win_by'],axis=1, inplace=True)

# %%
Numerical_columns = ['hero_KD', 'opp_KD', 'hero_SIG_STR_pct',
       'opp_SIG_STR_pct', 'hero_TD_pct', 'opp_TD_pct', 'hero_SUB_ATT', 'opp_SUB_ATT',
        'hero_REV', 'opp_REV', 'hero_SIG_STR._att', 'hero_SIG_STR._landed',
       'opp_SIG_STR._att', 'opp_SIG_STR._landed', 'hero_TOTAL_STR._att',
       'hero_TOTAL_STR._landed', 'opp_TOTAL_STR._att', 'opp_TOTAL_STR._landed',
       'hero_TD_att', 'hero_TD_landed', 'opp_TD_att', 'opp_TD_landed', 'hero_HEAD_att',
       'hero_HEAD_landed', 'opp_HEAD_att', 'opp_HEAD_landed', 'hero_BODY_att',
       'hero_BODY_landed', 'opp_BODY_att', 'opp_BODY_landed', 'hero_LEG_att',
       'hero_LEG_landed', 'opp_LEG_att', 'opp_LEG_landed', 'hero_DISTANCE_att',
       'hero_DISTANCE_landed', 'opp_DISTANCE_att', 'opp_DISTANCE_landed',
       'hero_CLINCH_att', 'hero_CLINCH_landed', 'opp_CLINCH_att', 'opp_CLINCH_landed',
       'hero_GROUND_att', 'hero_GROUND_landed', 'opp_GROUND_att', 'opp_GROUND_landed', 
        'hero_CTRL_time(seconds)', 'opp_CTRL_time(seconds)',
       'total_time_fought(seconds)']

Categorical_columns = ['win_by', 'last_round',
        'Winner', 'title_bout']

# %% [markdown]
# For all `Numerical_columns`, we take the average of those columns for every fighter of every fight they had up until that point.
#
# For `Categorical_columns`, we have to come up with different ideas for each column:
#
# * Each `win_by` will be a column of it's own
# * from `last_round` we can get, `total_rounds_fought`
# * from `total_time_fought` we can get `average_time_fought`
# * from `Winner` we get `wins`, `losses`, `draw`, `current_streak`, `longest_streak`
# * from `title_bout` we can get `no_of_title_fights`

# %%
import re

def lreplace(pattern, sub, string):
    """
    Replaces 'pattern' in 'string' with 'sub' if 'pattern' starts 'string'.
    """
    return re.sub('^%s' % pattern, sub, string)

# %%
red = df.groupby('R_fighter')
blue = df.groupby('B_fighter')

# %%
def get_fighter_red(fighter_name):
    try:
        fighter_red = red.get_group(fighter_name)
    except:
        return None
    rename_columns = {}
    for column in fighter_red.columns:
        if re.search('^R_', column) is not None:
            rename_columns[column] = lreplace('R_', 'hero_', column)
        elif re.search('^B_', column) is not None:
            rename_columns[column] = lreplace('B_', 'opp_', column)
    fighter_red = fighter_red.rename(rename_columns, axis='columns')
    return fighter_red

# %%
def get_fighter_blue(fighter_name):
    try:
        fighter_blue = blue.get_group(fighter_name)
    except:
        return None
    rename_columns = {}
    for column in fighter_blue.columns:
        if re.search('^B_', column) is not None:
            rename_columns[column] = lreplace('B_', 'hero_', column)
        elif re.search('^R_', column) is not None:
            rename_columns[column] = lreplace('R_', 'opp_', column)
    fighter_blue = fighter_blue.rename(rename_columns, axis='columns')
    return fighter_blue

# %%
def get_result_stats(result_list):
    result_list.reverse() # To get it in ascending order
    current_win_streak = 0
    current_lose_streak = 0
    longest_win_streak = 0
    wins = 0
    losses = 0
    draw = 0
    for result in result_list:
        if result == 'hero':
            wins += 1
            current_win_streak += 1
            current_lose_streak = 0
            if longest_win_streak < current_win_streak:
                longest_win_streak += 1
        elif result == 'opp':
            losses += 1
            current_win_streak = 0
            current_lose_streak += 1
        elif result == 'draw':
            draw += 1
            current_lose_streak = 0
            current_win_streak = 0
            
    return current_win_streak, current_lose_streak, longest_win_streak, wins, losses, draw

# %%
win_by_columns = ['win_by_Decision - Majority', 'win_by_Decision - Split',
       'win_by_Decision - Unanimous', 'win_by_KO/TKO','win_by_Submission',
       'win_by_TKO - Doctor\'s Stoppage']

# %%
temp_blue_frame = pd.DataFrame()
temp_red_frame = pd.DataFrame()
result_stats = ['current_win_streak', 'current_lose_streak', 'longest_win_streak', 'wins', 'losses', 'draw']

for fighter_name in fighters:
    fighter_red = get_fighter_red(fighter_name)
    fighter_blue = get_fighter_blue(fighter_name)
    fighter_index = None
    
    if fighter_red is None:
        fighter = fighter_blue
        fighter_index = 'blue'
    elif fighter_blue is None:
        fighter = fighter_red
        fighter_index = 'red'
    else:
        fighter = pd.concat([fighter_red, fighter_blue]).sort_index()
    
    fighter['Winner'] = fighter['Winner'].apply(lambda X: 'hero' if X == fighter_name else 'opp')

    for i, index in enumerate(fighter.index):
        fighter_slice = fighter[(i+1):].sort_index(ascending=False)
        s = fighter_slice[Numerical_columns].ewm(span=3, adjust=False).mean().tail(1)
        if len(s) != 0:
            pass
        else:
            s.loc[len(s)] = [np.NaN for _ in s.columns]
        s['total_rounds_fought'] = fighter_slice['last_round'].sum()
        s['total_title_bouts'] = fighter_slice[fighter_slice['title_bout']==True]['title_bout'].count()
        s['hero_fighter'] = fighter_name
        results = get_result_stats(list(fighter_slice['Winner']))
        for result_stat, result in zip(result_stats, results):
            s[result_stat] = result
        win_by_results = fighter_slice[fighter_slice['Winner'] == 'hero'][win_by_columns].sum()
        for win_by_column,win_by_result in zip(win_by_columns, win_by_results):
            s[win_by_column] = win_by_result
        s.index = [index]


        if fighter_index is None:
            if index in fighter_blue.index:
                temp_blue_frame = temp_blue_frame.append(s)
            elif index in fighter_red.index:
                temp_red_frame = temp_red_frame.append(s)
        elif fighter_index == 'blue':
            temp_blue_frame = temp_blue_frame.append(s)
        elif fighter_index == 'red':
            temp_red_frame = temp_red_frame.append(s)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5228\2877040980.py in ?()
#      40         if fighter_index is None:
#      41             if index in fighter_blue.index:
#      42                 temp_blue_frame = temp_blue_frame.append(s)
#      43             elif index in fighter_red.index:
# ---> 44                 temp_red_frame = temp_red_frame.append(s)
#      45         elif fighter_index == 'blue':
#      46             temp_blue_frame = temp_blue_frame.append(s)
#      47         elif fighter_index == 'red':
#
# c:\Users\JT\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
temp_blue_frame.T
# Out:
#                                 3483 3604     1782    2001       1708  \
# hero_KD                            1  NaN        0       0   0.375095
# opp_KD                             0  NaN      0.5       0    1.53516
# hero_SIG_STR_pct                0.42  NaN   0.4475   0.485   0.546008
# opp_SIG_STR_pct                 0.43  NaN  0.40875  0.4275   0.536013
# hero_TD_pct                        1  NaN   0.0825   0.165  0.0369015
# ...                              ...  ...      ...     ...        ...
# win_by_Decision - Split            0    0        0       0          1
# win_by_Decision - Unanimous        1    0        1       1          4
# win_by_KO/TKO                      0    0        0       0          4
# win_by_Submission                  0    0        1       1          0
# win_by_TKO - Doctor's Stoppage     0    0        0       0          0
#
#                                      2104       3818       4812    5173  \
# hero_KD                          0.750191  0.0488281   0.390625     0.5
# opp_KD                          0.0703125          0          0       0
# hero_SIG_STR_pct                 0.602016   0.376074   0.428594   0.475
# opp_SIG_STR_pct                  0.462026   0.598701   0.429609  0.4475
# hero_TD_pct                     0.0738029   0.253555  0.0284375    0.25
# ...                                   ...        ...        ...     ...
# win_by_Decision - Split                 1          1          1       0
# win_by_Decision - Unanimous             4          1          1       0
# win_by_KO/TKO                           4          2          2       0
# win_by_Submission                       0          0          0       0
# win_by_TKO - Doctor's Stoppage          0          0          0       0
#
#                                  5342  ...   5027 5182   5432 5565    2540  \
# hero_KD                             1  ...      0  NaN      0  NaN    0.25
# opp_KD                              0  ...      0  NaN      0  NaN    0.25
# hero_SIG_STR_pct                 0.54  ...    0.4  NaN  0.385  NaN  0.3925
# opp_SIG_STR_pct                 0.485  ...   0.38  NaN  0.425  NaN  0.3925
# hero_TD_pct                         0  ...  0.205  NaN    0.1  NaN    0.75
# ...                               ...  ...    ...  ...    ...  ...     ...
# win_by_Decision - Split             0  ...      0    0      0    0       0
# win_by_Decision - Unanimous         0  ...      1    0      0    0       0
# win_by_KO/TKO                       0  ...      0    0      2    0       1
# win_by_Submission                   0  ...      0    0      0    0       0
# win_by_TKO - Doctor's Stoppage      0  ...      0    0      0    0       0
#
#                                3016 250       3301      3513  4266
# hero_KD                         NaN  NaN   0.15625    0.3125     0
# opp_KD                          NaN  NaN   0.28125    0.5625     2
# hero_SIG_STR_pct                NaN  NaN  0.491875   0.60375  0.42
# opp_SIG_STR_pct                 NaN  NaN  0.479063  0.418125  0.46
# hero_TD_pct                     NaN  NaN  0.152969  0.305938   0.5
# ...                             ...  ...       ...       ...   ...
# win_by_Decision - Split           0    0         0         0     0
# win_by_Decision - Unanimous       0    0         2         2     0
# win_by_KO/TKO                     0    0         3         3     1
# win_by_Submission                 0    0         0         0     0
# win_by_TKO - Doctor's Stoppage    0    0         0         0     0
#
# [64 rows x 5802 columns]

# %% [markdown]
# ### Adding fighter details like height, weight, reach, stance and dob

# %%
fighter_details = fighter_details[fighter_details.index.isin(fighters)]
for col in fighter_details.columns:
    print(f"Number of NaN in {col} : {fighter_details[col].isnull().sum()}")
# Out:
# Number of NaN in Height : 13
# Number of NaN in Weight : 10
# Number of NaN in Reach : 645
# Number of NaN in Stance : 75
# Number of NaN in DOB : 141
# Number of NaN in SLpM : 0
# Number of NaN in Str_Acc : 0
# Number of NaN in SApM : 0
# Number of NaN in Str_Def : 0
# Number of NaN in TD_Avg : 0
# Number of NaN in TD_Acc : 0
# Number of NaN in TD_Def : 0
# Number of NaN in Sub_Avg : 0

# %%
def convert_to_cms(X):
    if X is np.NaN:
        return X
    elif len(X.split("'")) == 2:
        feet = float(X.split("'")[0])
        inches = int(X.split("'")[1].replace(' ', '').replace('"',''))
        return (feet * 30.48) + (inches * 2.54)
    else:
        return float(X.replace('"','')) * 2.54

# %%
fighter_details['Height_cms'] = fighter_details['Height'].apply(convert_to_cms)
fighter_details['Reach_cms'] = fighter_details['Reach'].apply(convert_to_cms)

# %%
fighter_details['Weight_lbs'] = fighter_details['Weight'].apply(lambda X: float(X.replace(' lbs.', '')) if X is not np.NaN else X)

# %%
pct_columns = ['Str_Acc','Str_Def', 'TD_Acc', 'TD_Def']

def pct_to_frac(X):
    if X != np.NaN:
        return float(X.replace('%', ''))/100
    else:
        return 0

for column in pct_columns:
    fighter_details[column] = fighter_details[column].apply(pct_to_frac)

# %%
fighter_details.drop(['Height', 'Weight', 'Reach'], axis=1, inplace=True)

# %%
fighter_details.reset_index(inplace=True)
temp_red_frame.reset_index(inplace=True)
temp_blue_frame.reset_index(inplace=True)

# %%
temp_blue_frame = temp_blue_frame.merge(fighter_details, left_on='hero_fighter', right_on='fighter_name', how='left')
temp_blue_frame.set_index('index', inplace=True)

# %%
temp_blue_frame[['hero_fighter', 'fighter_name', 'Height_cms', 'Weight_lbs', 'DOB']].head(20)
# Out:
#           hero_fighter     fighter_name  Height_cms  Weight_lbs           DOB
# index
# 3483   Kazuki Tokudome  Kazuki Tokudome      180.34       155.0  Mar 04, 1987
# 3604   Kazuki Tokudome  Kazuki Tokudome      180.34       155.0  Mar 04, 1987
# 1782      Bec Rawlings     Bec Rawlings      167.64       125.0  Feb 11, 1989
# 2001      Bec Rawlings     Bec Rawlings      167.64       125.0  Feb 11, 1989
# 1708      Patrick Cote     Patrick Cote      180.34       170.0  Feb 29, 1980
# 2104      Patrick Cote     Patrick Cote      180.34       170.0  Feb 29, 1980
# 3818      Patrick Cote     Patrick Cote      180.34       170.0  Feb 29, 1980
# 4812      Patrick Cote     Patrick Cote      180.34       170.0  Feb 29, 1980
# 5173      Patrick Cote     Patrick Cote      180.34       170.0  Feb 29, 1980
# 5342      Patrick Cote     Patrick Cote      180.34       170.0  Feb 29, 1980
# 5363      Patrick Cote     Patrick Cote      180.34       170.0  Feb 29, 1980
# 5383      Patrick Cote     Patrick Cote      180.34       170.0  Feb 29, 1980
# 5685        Sam Fulton       Sam Fulton         NaN         NaN           NaN
# 4768          Tom Egan         Tom Egan      180.34       170.0           NaN
# 4545      Kyle Bradley     Kyle Bradley      175.26       155.0  Aug 19, 1982
# 4839      Kyle Bradley     Kyle Bradley      175.26       155.0  Aug 19, 1982
# 4952      Kyle Bradley     Kyle Bradley      175.26       155.0  Aug 19, 1982
# 427      Vicente Luque    Vicente Luque      180.34       170.0  Nov 27, 1991
# 1725     Vicente Luque    Vicente Luque      180.34       170.0  Nov 27, 1991
# 2313     Vicente Luque    Vicente Luque      180.34       170.0  Nov 27, 1991

# %%
temp_red_frame = temp_red_frame.merge(fighter_details, left_on='hero_fighter', right_on='fighter_name', how='left')
temp_red_frame.set_index('index', inplace=True)

# %%
temp_blue_frame.drop('fighter_name', axis=1, inplace=True)
temp_red_frame.drop('fighter_name', axis=1, inplace=True)

# %%
blue_frame = temp_blue_frame.add_prefix('B_')
red_frame = temp_red_frame.add_prefix('R_')

# %%
frame = blue_frame.join(red_frame, how='outer')

# %%
rename_cols = {}
for col in frame.columns:
    if 'hero' in col:
        rename_cols[col] = col.replace('_hero_', '_avg_').replace('.', '')
    if 'opp' in col:
        rename_cols[col] = col.replace('_opp_', '_avg_opp_').replace('.', '')
    if 'win_by' in col:
        rename_cols[col] = col.replace(' ', '').replace('-', '_').replace('\'s', '_')

# %%
frame.rename(rename_cols, axis='columns', inplace=True)

# %%
frame.drop(['R_avg_fighter','B_avg_fighter'], axis=1, inplace=True)

# %%
df2 = df2.join(frame, how='outer')

# %% [markdown]
# ### Create Age

# %%
df2['R_DOB'] = pd.to_datetime(df2['R_DOB'])
df2['B_DOB'] = pd.to_datetime(df2['B_DOB'])
df2['date'] = pd.to_datetime(df2['date'])

# %%
def get_age(row):
    B_age = (row['date'] - row['B_DOB']).days
    R_age = (row['date'] - row['R_DOB']).days
    if np.isnan(B_age)!=True:
        B_age = math.floor(B_age/365.25)
    if np.isnan(R_age)!=True:
        R_age = math.floor(R_age/365.25)
    return pd.Series([B_age, R_age], index=['B_age', 'R_age'])

# %%
df2[['B_age', 'R_age']]= df2[['date', 'R_DOB', 'B_DOB']].apply(get_age, axis=1)

# %%
df2.drop(['R_DOB', 'B_DOB'], axis=1, inplace=True)

# %%
# df2.drop(df2.index[df2['Winner'] == 'draw'], inplace = True)

# %%
df2.to_csv('../data/data.csv', index=False)

# %%
df2
# Out:
#               R_fighter           B_fighter         Referee       date  \
# 0          Brian Ortega      Chan Sung Jung  Lukasz Bosacki 2020-10-17
# 1     Katlyn Chookagian     Jessica Andrade  Lukasz Bosacki 2020-10-17
# 2           Jimmy Crute  Modestas Bukauskas  Anders Ohlsson 2020-10-17
# 3         Claudio Silva        James Krause  Lukasz Bosacki 2020-10-17
# 4        Thomas Almeida   Jonathan Martinez  Anders Ohlsson 2020-10-17
# ...                 ...                 ...             ...        ...
# 5797       Orlando Wiet    Robert Lucarelli   John McCarthy 1994-03-11
# 5798      Frank Hamaker     Thaddeus Luster   John McCarthy 1994-03-11
# 5799      Johnny Rhodes       David Levicki   John McCarthy 1994-03-11
# 5800      Patrick Smith          Ray Wizard   John McCarthy 1994-03-11
# 5801       Scott Morris      Sean Daugherty   John McCarthy 1994-03-11
#
#                                         location Winner  title_bout  \
# 0     Abu Dhabi, Abu Dhabi, United Arab Emirates    Red       False
# 1     Abu Dhabi, Abu Dhabi, United Arab Emirates   Blue       False
# 2     Abu Dhabi, Abu Dhabi, United Arab Emirates    Red       False
# 3     Abu Dhabi, Abu Dhabi, United Arab Emirates   Blue       False
# 4     Abu Dhabi, Abu Dhabi, United Arab Emirates   Blue       False
# ...                                          ...    ...         ...
# 5797                       Denver, Colorado, USA    Red       False
# 5798                       Denver, Colorado, USA    Red       False
# 5799                       Denver, Colorado, USA    Red       False
# 5800                       Denver, Colorado, USA    Red       False
# 5801                       Denver, Colorado, USA    Red       False
#
#            weight_class  no_of_rounds  B_avg_KD  ...  R_Str_Def  R_TD_Avg  \
# 0         Featherweight             5  0.820312  ...       0.52      0.80
# 1     Women's Flyweight             3  0.062622  ...       0.62      0.30
# 2     Light Heavyweight             3  0.000000  ...       0.54      4.33
# 3          Welterweight             3  0.750000  ...       0.43      3.01
# 4         Featherweight             3  1.625000  ...       0.64      0.00
# ...                 ...           ...       ...  ...        ...       ...
# 5797        Open Weight             1       NaN  ...       0.00      0.00
# 5798        Open Weight             1       NaN  ...       0.00      0.00
# 5799        Open Weight             1       NaN  ...       0.00      0.00
# 5800        Open Weight             1       NaN  ...       0.00      0.00
# 5801        Open Weight             1       NaN  ...       0.00      0.00
#
#       R_TD_Acc  R_TD_Def  R_Sub_Avg  R_Height_cms  R_Reach_cms  R_Weight_lbs  \
# 0         0.21      0.56        1.1        172.72       175.26         145.0
# 1         0.15      0.48        0.5        175.26       172.72         125.0
# 2         0.75      0.60        2.4        187.96       187.96         205.0
# 3         0.28      0.66        1.6        180.34       180.34         170.0
# 4         0.00      0.75        0.0        170.18       177.80         145.0
# ...        ...       ...        ...           ...          ...           ...
# 5797      0.00      0.00        0.0        177.80          NaN         170.0
# 5798      0.00      0.00        0.0           NaN          NaN           NaN
# 5799      0.00      0.00        0.0        182.88          NaN         210.0
# 5800      0.00      0.00        0.0        187.96          NaN         225.0
# 5801      0.00      0.00        0.0        177.80          NaN         210.0
#
#       B_age  R_age
# 0      33.0   29.0
# 1      29.0   31.0
# 2      26.0   24.0
# 3      34.0   38.0
# 4      26.0   29.0
# ...     ...    ...
# 5797    NaN    NaN
# 5798    NaN    NaN
# 5799    NaN    NaN
# 5800    NaN   30.0
# 5801   18.0    NaN
#
# [5802 rows x 161 columns]
