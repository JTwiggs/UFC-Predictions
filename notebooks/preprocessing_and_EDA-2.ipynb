# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('../data/data.csv')

# %%
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_rows', 200)

# %%
df.T
# Out:
#                                                 0                       1     \
# R_fighter                             Justin Gaethje            Amanda Lemos
# B_fighter                              Rafael Fiziev          Iasmin Lucindo
# Referee                                 Jason Herzog          Keith Peterson
# date                                      2025-03-08              2025-03-08
# location                      Las Vegas, Nevada, USA  Las Vegas, Nevada, USA
# Winner                                           Red                     Red
# title_bout                                     False                   False
# weight_class                             Lightweight     Women's Strawweight
# no_of_rounds                                       3                       3
# B_avg_KD                                    0.140625                     0.0
# B_avg_opp_KD                                0.003906                     0.0
# B_avg_SIG_STR_pct                           0.540078                 0.45875
# B_avg_opp_SIG_STR_pct                       0.474609                0.344375
# B_avg_TD_pct                                0.007812                  0.6325
# B_avg_opp_TD_pct                            0.193125                 0.54125
# B_avg_SUB_ATT                                    0.0                   0.125
# B_avg_opp_SUB_ATT                                0.0                     0.0
# B_avg_REV                                        0.0                     0.5
# B_avg_opp_REV                                    0.0                     0.0
# B_avg_SIG_STR_att                            94.8125                 92.1875
# B_avg_SIG_STR_landed                       49.824219                 44.4375
# B_avg_opp_SIG_STR_att                      94.207031                103.0625
# B_avg_opp_SIG_STR_landed                   49.675781                 35.4375
# B_avg_TOTAL_STR_att                        99.996094                   113.0
# B_avg_TOTAL_STR_landed                     53.882812                 61.8125
# B_avg_opp_TOTAL_STR_att                   102.738281                  128.25
# B_avg_opp_TOTAL_STR_landed                 55.699219                   56.75
# B_avg_TD_att                                0.160156                  4.1875
# B_avg_TD_landed                             0.011719                     2.5
# B_avg_opp_TD_att                            6.152344                   1.375
# B_avg_opp_TD_landed                           1.0625                   0.625
# B_avg_HEAD_att                                54.875                 70.3125
# B_avg_HEAD_landed                          19.703125                 28.0625
# B_avg_opp_HEAD_att                         73.410156                   80.75
# B_avg_opp_HEAD_landed                      34.539062                  22.125
# B_avg_BODY_att                             33.578125                 16.9375
# B_avg_BODY_landed                          24.976562                  12.875
# B_avg_opp_BODY_att                         11.351562                 12.6875
# B_avg_opp_BODY_landed                       8.570312                   8.125
# B_avg_LEG_att                               6.359375                  4.9375
# B_avg_LEG_landed                            5.144531                     3.5
# B_avg_opp_LEG_att                           9.445312                   9.625
# B_avg_opp_LEG_landed                        6.566406                  5.1875
# B_avg_DISTANCE_att                         89.132812                   81.25
# B_avg_DISTANCE_landed                      45.042969                 36.0625
# B_avg_opp_DISTANCE_att                     84.785156                 97.8125
# B_avg_opp_DISTANCE_landed                  42.640625                 31.6875
# B_avg_CLINCH_att                            5.398438                    6.25
# B_avg_CLINCH_landed                            4.625                     4.0
# B_avg_opp_CLINCH_att                        7.394531                    4.25
# B_avg_opp_CLINCH_landed                     6.007812                    2.75
# B_avg_GROUND_att                             0.28125                  4.6875
# B_avg_GROUND_landed                          0.15625                   4.375
# B_avg_opp_GROUND_att                        2.027344                     1.0
# B_avg_opp_GROUND_landed                     1.027344                     1.0
# B_avg_CTRL_time(seconds)                     24.9375                 258.125
# B_avg_opp_CTRL_time(seconds)               93.171875                 25.0625
# B_total_time_fought(seconds)              677.835938                  852.75
# B_total_rounds_fought                             24                      14
# B_total_title_bouts                                0                       0
# B_current_win_streak                               0                       0
# B_current_lose_streak                              1                       1
# B_longest_win_streak                               6                       4
# B_wins                                             6                       4
# B_losses                                           3                       1
# B_draw                                             0                       0
# B_win_by_Decision_Majority                         0                       0
# B_win_by_Decision_Split                            0                       1
# B_win_by_Decision_Unanimous                        3                       2
# B_win_by_KO/TKO                                    3                       0
# B_win_by_Submission                                0                       1
# B_win_by_TKO_Doctor_Stoppage                       0                       0
# B_Stance                                      Switch                Orthodox
# B_SLpM                                          4.85                    2.94
# B_Str_Acc                                       0.52                    0.44
# B_SApM                                          4.95                    2.53
# B_Str_Def                                       0.48                    0.65
# B_TD_Avg                                         0.5                    2.15
# B_TD_Acc                                        0.57                     0.6
# B_TD_Def                                         0.9                    0.54
# B_Sub_Avg                                        0.0                     0.2
# B_Height_cms                                  172.72                  160.02
# B_Reach_cms                                   180.34                  167.64
# B_Weight_lbs                                   155.0                   115.0
# R_avg_KD                                    0.350586                0.266602
# R_avg_opp_KD                                0.562744                   0.125
# R_avg_SIG_STR_pct                           0.564321                0.350889
# R_avg_opp_SIG_STR_pct                       0.552739                0.363857
# R_avg_TD_pct                                 0.04125                0.283203
# R_avg_opp_TD_pct                            0.015515                0.305469
# R_avg_SUB_ATT                                    0.0                0.844238
# R_avg_opp_SUB_ATT                           0.140625                2.015625
# R_avg_REV                                        0.0                 0.53125
# R_avg_opp_REV                                    0.0                1.007812
# R_avg_SIG_STR_att                         147.923584               38.261719
# R_avg_SIG_STR_landed                       81.446289               17.389648
# R_avg_opp_SIG_STR_att                     203.373535               50.824219
# R_avg_opp_SIG_STR_landed                  116.184082                29.26123
# R_avg_TOTAL_STR_att                       149.006836               42.952148
# R_avg_TOTAL_STR_landed                     82.357422               22.054688
# R_avg_opp_TOTAL_STR_att                   203.723633               87.854492
# R_avg_opp_TOTAL_STR_landed                116.407959               64.175293
# R_avg_TD_att                                0.375244                0.651367
# R_avg_TD_landed                                0.125                 0.56543
# R_avg_opp_TD_att                            0.300537                4.258789
# R_avg_opp_TD_landed                         0.062988                1.539062
# R_avg_HEAD_att                              98.07373               30.730957
# R_avg_HEAD_landed                          42.443115               11.671387
# R_avg_opp_HEAD_att                        109.987549               38.169922
# R_avg_opp_HEAD_landed                      45.076172               20.362793
# R_avg_BODY_att                             25.385986                4.183594
# R_avg_BODY_landed                          17.054688                3.222656
# R_avg_opp_BODY_att                         56.553955                6.814453
# R_avg_opp_BODY_landed                      40.508301                 5.21875
# R_avg_LEG_att                              24.463867                3.347168
# R_avg_LEG_landed                           21.948486                2.495605
# R_avg_opp_LEG_att                          36.832031                5.839844
# R_avg_opp_LEG_landed                       30.599609                3.679688
# R_avg_DISTANCE_att                        143.070312               30.898438
# R_avg_DISTANCE_landed                      77.457764               12.075195
# R_avg_opp_DISTANCE_att                    198.896729               29.996582
# R_avg_opp_DISTANCE_landed                 112.898926               12.844727
# R_avg_CLINCH_att                            4.152344                1.109863
# R_avg_CLINCH_landed                         3.448242                 0.64209
# R_avg_opp_CLINCH_att                        4.272217                 2.70166
# R_avg_opp_CLINCH_landed                     3.143555                2.291016
# R_avg_GROUND_att                            0.700928                6.253418
# R_avg_GROUND_landed                         0.540283                4.672363
# R_avg_opp_GROUND_att                         0.20459               18.125977
# R_avg_opp_GROUND_landed                     0.141602               14.125488
# R_avg_CTRL_time(seconds)                    4.827148              103.436523
# R_avg_opp_CTRL_time(seconds)                3.406738              410.542969
# R_total_time_fought(seconds)             1012.181885              771.955078
# R_total_rounds_fought                             33                      27
# R_total_title_bouts                                2                       1
# R_current_win_streak                               1                       0
# R_current_lose_streak                              0                       1
# R_longest_win_streak                               4                       5
# R_wins                                             8                       8
# R_losses                                           5                       4
# R_draw                                             0                       0
# R_win_by_Decision_Majority                         1                       0
# R_win_by_Decision_Split                            0                       1
# R_win_by_Decision_Unanimous                        1                       2
# R_win_by_KO/TKO                                    6                       3
# R_win_by_Submission                                0                       2
# R_win_by_TKO_Doctor_Stoppage                       0                       0
# R_Stance                                    Orthodox                Southpaw
# R_SLpM                                          6.59                    2.89
# R_Str_Acc                                       0.58                    0.54
# R_SApM                                          7.18                    3.46
# R_Str_Def                                       0.51                    0.44
# R_TD_Avg                                         0.1                    1.14
# R_TD_Acc                                        0.14                    0.62
# R_TD_Def                                        0.68                    0.59
# R_Sub_Avg                                        0.0                     0.7
# R_Height_cms                                  180.34                  162.56
# R_Reach_cms                                    177.8                   165.1
# R_Weight_lbs                                   155.0                   115.0
# B_age                                           32.0                    23.0
# R_age                                           36.0                    37.0
#
#                                                 2                       3     \
# R_fighter                               Jalin Turner              Joshua Van
# B_fighter                         Ignacio Bahamondes             Rei Tsuruya
# Referee                                   Mark Smith            Jason Herzog
# date                                      2025-03-08              2025-03-08
# location                      Las Vegas, Nevada, USA  Las Vegas, Nevada, USA
# Winner                                          Blue                     Red
# title_bout                                     False                   False
# weight_class                             Lightweight               Flyweight
# no_of_rounds                                       3                       3
# B_avg_KD                                    1.265625                     0.0
# B_avg_opp_KD                                     0.0                     0.0
# B_avg_SIG_STR_pct                           0.510781                    0.53
# B_avg_opp_SIG_STR_pct                       0.434844                     0.5
# B_avg_TD_pct                                     0.0                    0.37
# B_avg_opp_TD_pct                            0.082812                     0.5
# B_avg_SUB_ATT                                 0.0625                     0.0
# B_avg_opp_SUB_ATT                                0.0                     0.0
# B_avg_REV                                        0.0                     0.0
# B_avg_opp_REV                                    0.0                     0.0
# B_avg_SIG_STR_att                             90.375                    32.0
# B_avg_SIG_STR_landed                       44.390625                    17.0
# B_avg_opp_SIG_STR_att                       63.34375                    32.0
# B_avg_opp_SIG_STR_landed                   28.171875                    16.0
# B_avg_TOTAL_STR_att                         97.40625                    83.0
# B_avg_TOTAL_STR_landed                     49.859375                    62.0
# B_avg_opp_TOTAL_STR_att                     69.65625                    45.0
# B_avg_opp_TOTAL_STR_landed                   33.6875                    26.0
# B_avg_TD_att                                  0.1875                     8.0
# B_avg_TD_landed                                  0.0                     3.0
# B_avg_opp_TD_att                                1.25                     2.0
# B_avg_opp_TD_landed                          0.40625                     1.0
# B_avg_HEAD_att                             67.171875                    30.0
# B_avg_HEAD_landed                             28.875                    15.0
# B_avg_opp_HEAD_att                         46.609375                    23.0
# B_avg_opp_HEAD_landed                      15.171875                     7.0
# B_avg_BODY_att                                 12.25                     2.0
# B_avg_BODY_landed                           8.109375                     2.0
# B_avg_opp_BODY_att                          10.78125                     5.0
# B_avg_opp_BODY_landed                       8.578125                     5.0
# B_avg_LEG_att                              10.953125                     0.0
# B_avg_LEG_landed                             7.40625                     0.0
# B_avg_opp_LEG_att                           5.953125                     4.0
# B_avg_opp_LEG_landed                        4.421875                     4.0
# B_avg_DISTANCE_att                         69.203125                    12.0
# B_avg_DISTANCE_landed                       31.78125                     2.0
# B_avg_opp_DISTANCE_att                      56.15625                    23.0
# B_avg_opp_DISTANCE_landed                  21.984375                     8.0
# B_avg_CLINCH_att                             6.21875                     3.0
# B_avg_CLINCH_landed                         4.390625                     2.0
# B_avg_opp_CLINCH_att                         4.78125                     5.0
# B_avg_opp_CLINCH_landed                      4.65625                     4.0
# B_avg_GROUND_att                           14.953125                    17.0
# B_avg_GROUND_landed                          8.21875                    13.0
# B_avg_opp_GROUND_att                         2.40625                     4.0
# B_avg_opp_GROUND_landed                      1.53125                     4.0
# B_avg_CTRL_time(seconds)                    28.84375                   379.0
# B_avg_opp_CTRL_time(seconds)               60.578125                   269.0
# B_total_time_fought(seconds)              393.171875                   900.0
# B_total_rounds_fought                             17                       3
# B_total_title_bouts                                0                       0
# B_current_win_streak                               0                       1
# B_current_lose_streak                              1                       0
# B_longest_win_streak                               3                       1
# B_wins                                             5                       1
# B_losses                                           2                       0
# B_draw                                             0                       0
# B_win_by_Decision_Majority                         0                       0
# B_win_by_Decision_Split                            0                       0
# B_win_by_Decision_Unanimous                        1                       1
# B_win_by_KO/TKO                                    3                       0
# B_win_by_Submission                                1                       0
# B_win_by_TKO_Doctor_Stoppage                       0                       0
# B_Stance                                    Orthodox                Orthodox
# B_SLpM                                          7.09                    2.24
# B_Str_Acc                                       0.47                    0.52
# B_SApM                                          4.36                    2.01
# B_Str_Def                                       0.57                    0.42
# B_TD_Avg                                         0.0                    5.06
# B_TD_Acc                                         0.0                    0.37
# B_TD_Def                                        0.85                     0.5
# B_Sub_Avg                                        0.5                     1.9
# B_Height_cms                                   190.5                  167.64
# B_Reach_cms                                    190.5                  172.72
# B_Weight_lbs                                   155.0                   125.0
# R_avg_KD                                    0.836426                  0.0625
# R_avg_opp_KD                                0.125488                   0.125
# R_avg_SIG_STR_pct                            0.46686                0.548438
# R_avg_opp_SIG_STR_pct                       0.568062                0.376563
# R_avg_TD_pct                                0.068594                0.453125
# R_avg_opp_TD_pct                            0.191699                0.151875
# R_avg_SUB_ATT                               0.049805                     0.0
# R_avg_opp_SUB_ATT                           0.126953                    0.25
# R_avg_REV                                   0.000977                     0.0
# R_avg_opp_REV                               0.005859                 0.03125
# R_avg_SIG_STR_att                          66.366699                 244.125
# R_avg_SIG_STR_landed                       32.770508                134.1875
# R_avg_opp_SIG_STR_att                      68.827148                200.4375
# R_avg_opp_SIG_STR_landed                   40.137695                 74.4375
# R_avg_TOTAL_STR_att                        69.769043                  279.25
# R_avg_TOTAL_STR_landed                     35.994141                 165.625
# R_avg_opp_TOTAL_STR_att                   109.977539               206.78125
# R_avg_opp_TOTAL_STR_landed                 75.452148                   79.25
# R_avg_TD_att                                0.466797                   1.125
# R_avg_TD_landed                             0.152344                     1.0
# R_avg_opp_TD_att                            4.120605                   5.375
# R_avg_opp_TD_landed                         1.273438                 1.15625
# R_avg_HEAD_att                             50.924805                202.9375
# R_avg_HEAD_landed                          21.779785                   100.0
# R_avg_opp_HEAD_att                          53.71582               168.84375
# R_avg_opp_HEAD_landed                      28.469727                51.90625
# R_avg_BODY_att                             10.145996                   27.75
# R_avg_BODY_landed                           7.095703                    22.5
# R_avg_opp_BODY_att                          7.987305                    16.5
# R_avg_opp_BODY_landed                       5.677734                10.96875
# R_avg_LEG_att                               5.295898                 13.4375
# R_avg_LEG_landed                             3.89502                 11.6875
# R_avg_opp_LEG_att                           7.124023                15.09375
# R_avg_opp_LEG_landed                        5.990234                 11.5625
# R_avg_DISTANCE_att                         56.964844                224.8125
# R_avg_DISTANCE_landed                      24.977539               118.65625
# R_avg_opp_DISTANCE_att                     40.543457                198.6875
# R_avg_opp_DISTANCE_landed                  23.635742                   73.25
# R_avg_CLINCH_att                            3.546387                    14.5
# R_avg_CLINCH_landed                         3.128418                12.46875
# R_avg_opp_CLINCH_att                        5.076172                  1.5625
# R_avg_opp_CLINCH_landed                     3.311523                 1.03125
# R_avg_GROUND_att                            5.855469                  4.8125
# R_avg_GROUND_landed                         4.664551                  3.0625
# R_avg_opp_GROUND_att                        23.20752                  0.1875
# R_avg_opp_GROUND_landed                     13.19043                 0.15625
# R_avg_CTRL_time(seconds)                   10.811035                    85.0
# R_avg_opp_CTRL_time(seconds)              226.727539               118.46875
# R_total_time_fought(seconds)              499.340332                844.4375
# R_total_rounds_fought                             22                      17
# R_total_title_bouts                                0                       0
# R_current_win_streak                               0                       3
# R_current_lose_streak                              1                       0
# R_longest_win_streak                               5                       3
# R_wins                                             7                       5
# R_losses                                           5                       1
# R_draw                                             0                       0
# R_win_by_Decision_Majority                         0                       0
# R_win_by_Decision_Split                            0                       1
# R_win_by_Decision_Unanimous                        0                       3
# R_win_by_KO/TKO                                    4                       1
# R_win_by_Submission                                3                       0
# R_win_by_TKO_Doctor_Stoppage                       0                       0
# R_Stance                                    Southpaw                Orthodox
# R_SLpM                                          5.53                     8.1
# R_Str_Acc                                       0.48                    0.54
# R_SApM                                          4.55                    5.24
# R_Str_Def                                       0.41                     0.6
# R_TD_Avg                                        0.77                    1.11
# R_TD_Acc                                        0.55                    0.63
# R_TD_Def                                        0.75                     0.8
# R_Sub_Avg                                        1.1                     0.0
# R_Height_cms                                   190.5                   165.1
# R_Reach_cms                                   195.58                   165.1
# R_Weight_lbs                                   155.0                   125.0
# B_age                                           27.0                    22.0
# R_age                                           29.0                    23.0
#
#                                                 4                       5     \
# R_fighter                               Alex Pereira              King Green
# B_fighter                           Magomed Ankalaev          Mauricio Ruffy
# Referee                                 Marc Goddard           Chris Tognoni
# date                                      2025-03-08              2025-03-08
# location                      Las Vegas, Nevada, USA  Las Vegas, Nevada, USA
# Winner                                          Blue                    Blue
# title_bout                                      True                   False
# weight_class                       Light Heavyweight             Lightweight
# no_of_rounds                                       5                       3
# B_avg_KD                                    0.262573                     1.0
# B_avg_opp_KD                                0.015625                     0.0
# B_avg_SIG_STR_pct                           0.553444                   0.605
# B_avg_opp_SIG_STR_pct                       0.429452                    0.37
# B_avg_TD_pct                                0.148796                     0.0
# B_avg_opp_TD_pct                            0.000659                     0.0
# B_avg_SUB_ATT                                    0.0                     0.0
# B_avg_opp_SUB_ATT                           0.000122                     0.0
# B_avg_REV                                   0.000244                     0.0
# B_avg_opp_REV                                    0.0                     0.0
# B_avg_SIG_STR_att                          91.624634                    76.5
# B_avg_SIG_STR_landed                       47.176147                    46.0
# B_avg_opp_SIG_STR_att                      91.602051                   137.0
# B_avg_opp_SIG_STR_landed                   39.783569                    52.0
# B_avg_TOTAL_STR_att                       115.724365                    80.0
# B_avg_TOTAL_STR_landed                      66.03186                    49.5
# B_avg_opp_TOTAL_STR_att                    97.548096                   149.0
# B_avg_opp_TOTAL_STR_landed                 45.693481                    63.0
# B_avg_TD_att                                0.849854                     0.5
# B_avg_TD_landed                             0.285889                     0.0
# B_avg_opp_TD_att                            0.565552                     3.0
# B_avg_opp_TD_landed                          0.00415                     0.0
# B_avg_HEAD_att                             56.248169                    66.0
# B_avg_HEAD_landed                          17.966064                    37.0
# B_avg_opp_HEAD_att                          50.05603                    85.5
# B_avg_opp_HEAD_landed                       7.861206                    18.0
# B_avg_BODY_att                             19.992188                     4.5
# B_avg_BODY_landed                          14.983398                     3.0
# B_avg_opp_BODY_att                          9.711304                    34.0
# B_avg_opp_BODY_landed                       6.586182                    21.5
# B_avg_LEG_att                              15.384277                     6.0
# B_avg_LEG_landed                           14.226685                     6.0
# B_avg_opp_LEG_att                          31.834717                    17.5
# B_avg_opp_LEG_landed                       25.336182                    12.5
# B_avg_DISTANCE_att                         81.317261                    69.0
# B_avg_DISTANCE_landed                      40.847168                    39.5
# B_avg_opp_DISTANCE_att                     87.926392                   126.5
# B_avg_opp_DISTANCE_landed                  37.827515                    44.5
# B_avg_CLINCH_att                            5.430298                     2.0
# B_avg_CLINCH_landed                         3.280029                     2.0
# B_avg_opp_CLINCH_att                        3.550415                    10.5
# B_avg_opp_CLINCH_landed                     1.893555                     7.5
# B_avg_GROUND_att                            4.877075                     5.5
# B_avg_GROUND_landed                          3.04895                     4.5
# B_avg_opp_GROUND_att                        0.125244                     0.0
# B_avg_opp_GROUND_landed                       0.0625                     0.0
# B_avg_CTRL_time(seconds)                   107.95166                    10.0
# B_avg_opp_CTRL_time(seconds)               32.295288                    40.0
# B_total_time_fought(seconds)              733.843262                   591.0
# B_total_rounds_fought                             36                       4
# B_total_title_bouts                                1                       0
# B_current_win_streak                               0                       2
# B_current_lose_streak                              1                       0
# B_longest_win_streak                               9                       2
# B_wins                                            11                       2
# B_losses                                           3                       0
# B_draw                                             0                       0
# B_win_by_Decision_Majority                         0                       0
# B_win_by_Decision_Split                            0                       0
# B_win_by_Decision_Unanimous                        5                       1
# B_win_by_KO/TKO                                    6                       1
# B_win_by_Submission                                0                       0
# B_win_by_TKO_Doctor_Stoppage                       0                       0
# B_Stance                                    Orthodox                Orthodox
# B_SLpM                                          3.66                    4.54
# B_Str_Acc                                       0.52                    0.58
# B_SApM                                          2.46                    4.59
# B_Str_Def                                       0.57                    0.61
# B_TD_Avg                                         0.8                     0.0
# B_TD_Acc                                        0.22                     0.0
# B_TD_Def                                        0.87                     1.0
# B_Sub_Avg                                        0.0                     0.0
# B_Height_cms                                   190.5                  180.34
# B_Reach_cms                                    190.5                   190.5
# B_Weight_lbs                                   205.0                   155.0
# R_avg_KD                                    1.193359                0.313538
# R_avg_opp_KD                                0.015625                0.132815
# R_avg_SIG_STR_pct                           0.670645                0.644374
# R_avg_opp_SIG_STR_pct                       0.361504                0.495028
# R_avg_TD_pct                                0.007812                0.750341
# R_avg_opp_TD_pct                            0.035176                0.002185
# R_avg_SUB_ATT                                0.09375                0.031319
# R_avg_opp_SUB_ATT                             0.0625                1.000261
# R_avg_REV                                        0.0                0.000248
# R_avg_opp_REV                                    0.0                0.000004
# R_avg_SIG_STR_att                         130.533203              104.143484
# R_avg_SIG_STR_landed                       82.369141               62.062927
# R_avg_opp_SIG_STR_att                      113.53125                56.68367
# R_avg_opp_SIG_STR_landed                   38.742188               24.875432
# R_avg_TOTAL_STR_att                            137.0              104.749586
# R_avg_TOTAL_STR_landed                     88.640625               62.597372
# R_avg_opp_TOTAL_STR_att                   117.126953               58.980391
# R_avg_opp_TOTAL_STR_landed                 41.353516               26.441432
# R_avg_TD_att                                0.007812                0.778199
# R_avg_TD_landed                             0.007812                0.751265
# R_avg_opp_TD_att                            0.498047                0.127045
# R_avg_opp_TD_landed                         0.171875                0.004696
# R_avg_HEAD_att                             98.632812               74.379911
# R_avg_HEAD_landed                          55.472656               40.047194
# R_avg_opp_HEAD_att                         89.830078               38.915722
# R_avg_opp_HEAD_landed                          21.25               13.124894
# R_avg_BODY_att                                  15.0               18.407274
# R_avg_BODY_landed                          12.863281               12.957051
# R_avg_opp_BODY_att                         14.792969                5.997646
# R_avg_opp_BODY_landed                       9.859375                3.309985
# R_avg_LEG_att                              16.900391               11.356299
# R_avg_LEG_landed                           14.033203                9.058682
# R_avg_opp_LEG_att                           8.908203               11.770301
# R_avg_opp_LEG_landed                        7.632812                8.440553
# R_avg_DISTANCE_att                        120.382812               96.230799
# R_avg_DISTANCE_landed                      73.304688                55.98322
# R_avg_opp_DISTANCE_att                    111.400391               53.294137
# R_avg_opp_DISTANCE_landed                  37.292969               22.319814
# R_avg_CLINCH_att                            4.480469                2.324129
# R_avg_CLINCH_landed                         4.398438                1.932498
# R_avg_opp_CLINCH_att                        1.628906                0.834598
# R_avg_opp_CLINCH_landed                     1.009766                0.574944
# R_avg_GROUND_att                            5.669922                5.588556
# R_avg_GROUND_landed                         4.666016                 4.14721
# R_avg_opp_GROUND_att                        0.501953                2.554936
# R_avg_opp_GROUND_landed                     0.439453                1.980674
# R_avg_CTRL_time(seconds)                    2.724609                37.67706
# R_avg_opp_CTRL_time(seconds)               46.160156                2.723498
# R_total_time_fought(seconds)              772.949219              388.625609
# R_total_rounds_fought                             25                      61
# R_total_title_bouts                                6                       0
# R_current_win_streak                               4                       4
# R_current_lose_streak                              0                       0
# R_longest_win_streak                               5                       4
# R_wins                                             9                      13
# R_losses                                           1                      13
# R_draw                                             0                       0
# R_win_by_Decision_Majority                         0                       0
# R_win_by_Decision_Split                            1                       1
# R_win_by_Decision_Unanimous                        1                       7
# R_win_by_KO/TKO                                    7                       3
# R_win_by_Submission                                0                       2
# R_win_by_TKO_Doctor_Stoppage                       0                       0
# R_Stance                                    Orthodox                Orthodox
# R_SLpM                                           5.0                     6.4
# R_Str_Acc                                       0.62                    0.52
# R_SApM                                           3.5                    3.72
# R_Str_Def                                       0.53                    0.62
# R_TD_Avg                                        0.11                    1.22
# R_TD_Acc                                         0.5                    0.39
# R_TD_Def                                        0.78                    0.74
# R_Sub_Avg                                        0.2                     0.3
# R_Height_cms                                  193.04                   177.8
# R_Reach_cms                                   200.66                  180.34
# R_Weight_lbs                                   205.0                   155.0
# B_age                                           32.0                    28.0
# R_age                                           37.0                    38.0
#
#                                                 6                       7     \
# R_fighter                            Brunno Ferreira             Alex Morono
# B_fighter                            Armen Petrosyan             Carlos Leal
# Referee                                   Mark Smith          Keith Peterson
# date                                      2025-03-08              2025-03-08
# location                      Las Vegas, Nevada, USA  Las Vegas, Nevada, USA
# Winner                                           Red                    Blue
# title_bout                                     False                   False
# weight_class                            Middleweight            Welterweight
# no_of_rounds                                       3                       3
# B_avg_KD                                         0.0                     0.0
# B_avg_opp_KD                                     0.5                     0.0
# B_avg_SIG_STR_pct                           0.520625                    0.43
# B_avg_opp_SIG_STR_pct                       0.551562                    0.49
# B_avg_TD_pct                                  0.0625                    0.25
# B_avg_opp_TD_pct                            0.358125                     0.1
# B_avg_SUB_ATT                                    0.0                     0.0
# B_avg_opp_SUB_ATT                             0.3125                     0.0
# B_avg_REV                                    0.03125                     0.0
# B_avg_opp_REV                                    0.0                     0.0
# B_avg_SIG_STR_att                              119.0                   246.0
# B_avg_SIG_STR_landed                         64.1875                   107.0
# B_avg_opp_SIG_STR_att                           86.0                   222.0
# B_avg_opp_SIG_STR_landed                    47.28125                   109.0
# B_avg_TOTAL_STR_att                          125.875                   292.0
# B_avg_TOTAL_STR_landed                          69.5                   146.0
# B_avg_opp_TOTAL_STR_att                         93.5                   236.0
# B_avg_opp_TOTAL_STR_landed                   53.5625                   119.0
# B_avg_TD_att                                  0.3125                     4.0
# B_avg_TD_landed                                0.125                     1.0
# B_avg_opp_TD_att                              1.5625                    19.0
# B_avg_opp_TD_landed                            1.125                     2.0
# B_avg_HEAD_att                                61.125                   207.0
# B_avg_HEAD_landed                            19.4375                    72.0
# B_avg_opp_HEAD_att                          49.53125                   184.0
# B_avg_opp_HEAD_landed                       19.78125                    82.0
# B_avg_BODY_att                               14.6875                    20.0
# B_avg_BODY_landed                           10.59375                    16.0
# B_avg_opp_BODY_att                              21.0                    26.0
# B_avg_opp_BODY_landed                       16.53125                    15.0
# B_avg_LEG_att                                43.1875                    19.0
# B_avg_LEG_landed                            34.15625                    19.0
# B_avg_opp_LEG_att                           15.46875                    12.0
# B_avg_opp_LEG_landed                        10.96875                    12.0
# B_avg_DISTANCE_att                         114.40625                   231.0
# B_avg_DISTANCE_landed                       60.46875                    94.0
# B_avg_opp_DISTANCE_att                       84.0625                   197.0
# B_avg_opp_DISTANCE_landed                     45.625                    96.0
# B_avg_CLINCH_att                              3.5625                    15.0
# B_avg_CLINCH_landed                              3.0                    13.0
# B_avg_opp_CLINCH_att                          1.8125                    25.0
# B_avg_opp_CLINCH_landed                      1.53125                    13.0
# B_avg_GROUND_att                             1.03125                     0.0
# B_avg_GROUND_landed                          0.71875                     0.0
# B_avg_opp_GROUND_att                           0.125                     0.0
# B_avg_opp_GROUND_landed                        0.125                     0.0
# B_avg_CTRL_time(seconds)                    38.09375                    13.0
# B_avg_opp_CTRL_time(seconds)                76.15625                   194.0
# B_total_time_fought(seconds)                   593.0                   900.0
# B_total_rounds_fought                             15                       3
# B_total_title_bouts                                0                       0
# B_current_win_streak                               1                       0
# B_current_lose_streak                              0                       1
# B_longest_win_streak                               2                       0
# B_wins                                             3                       0
# B_losses                                           3                       1
# B_draw                                             0                       0
# B_win_by_Decision_Majority                         0                       0
# B_win_by_Decision_Split                            1                       0
# B_win_by_Decision_Unanimous                        2                       0
# B_win_by_KO/TKO                                    0                       0
# B_win_by_Submission                                0                       0
# B_win_by_TKO_Doctor_Stoppage                       0                       0
# B_Stance                                    Orthodox                Orthodox
# B_SLpM                                          5.84                    9.65
# B_Str_Acc                                       0.53                     0.5
# B_SApM                                          3.31                    7.73
# B_Str_Def                                       0.53                    0.53
# B_TD_Avg                                        0.17                    0.78
# B_TD_Acc                                        0.33                    0.25
# B_TD_Def                                        0.41                     0.9
# B_Sub_Avg                                        0.0                     0.0
# B_Height_cms                                   190.5                  180.34
# B_Reach_cms                                   180.34                  187.96
# B_Weight_lbs                                   185.0                   170.0
# R_avg_KD                                      0.4375                0.019597
# R_avg_opp_KD                                     0.0                0.023561
# R_avg_SIG_STR_pct                             0.4875                0.325329
# R_avg_opp_SIG_STR_pct                       0.465625                0.451704
# R_avg_TD_pct                                 0.03125                0.281592
# R_avg_opp_TD_pct                              0.4375                0.841376
# R_avg_SUB_ATT                                    0.5                0.156292
# R_avg_opp_SUB_ATT                                1.0                     0.0
# R_avg_REV                                        0.5                0.000031
# R_avg_opp_REV                                    0.0                0.250496
# R_avg_SIG_STR_att                               53.0              215.409997
# R_avg_SIG_STR_landed                         24.4375               71.330446
# R_avg_opp_SIG_STR_att                           46.0              223.538169
# R_avg_opp_SIG_STR_landed                     20.8125              103.609819
# R_avg_TOTAL_STR_att                          60.8125              231.390954
# R_avg_TOTAL_STR_landed                        29.375               85.385355
# R_avg_opp_TOTAL_STR_att                       58.125              237.715012
# R_avg_opp_TOTAL_STR_landed                   30.8125               115.71682
# R_avg_TD_att                                   0.625                 0.91147
# R_avg_TD_landed                                0.125                0.313721
# R_avg_opp_TD_att                              4.6875                2.847418
# R_avg_opp_TD_landed                           2.3125                2.072567
# R_avg_HEAD_att                               43.3125              189.699217
# R_avg_HEAD_landed                            17.1875               55.229975
# R_avg_opp_HEAD_att                           33.4375               144.55936
# R_avg_opp_HEAD_landed                        10.3125               47.300961
# R_avg_BODY_att                                   8.5               18.192502
# R_avg_BODY_landed                              6.125                9.896773
# ...
# B_win_by_KO/TKO                                   0                      0
# B_win_by_Submission                               0                      0
# B_win_by_TKO_Doctor_Stoppage                      0                      0
# B_Stance                                        NaN                    NaN
# B_SLpM                                          0.0                    0.0
# B_Str_Acc                                       0.0                    0.0
# B_SApM                                          0.0                    0.0
# B_Str_Def                                       0.0                    0.0
# B_TD_Avg                                        0.0                    0.0
# B_TD_Acc                                        0.0                    0.0
# B_TD_Def                                        0.0                    0.0
# B_Sub_Avg                                       0.0                    0.0
# B_Height_cms                                    NaN                  190.5
# B_Reach_cms                                     NaN                    NaN
# B_Weight_lbs                                    NaN                  210.0
# R_avg_KD                                        NaN                    NaN
# R_avg_opp_KD                                    NaN                    NaN
# R_avg_SIG_STR_pct                               NaN                    NaN
# R_avg_opp_SIG_STR_pct                           NaN                    NaN
# R_avg_TD_pct                                    NaN                    NaN
# R_avg_opp_TD_pct                                NaN                    NaN
# R_avg_SUB_ATT                                   NaN                    NaN
# R_avg_opp_SUB_ATT                               NaN                    NaN
# R_avg_REV                                       NaN                    NaN
# R_avg_opp_REV                                   NaN                    NaN
# R_avg_SIG_STR_att                               NaN                    NaN
# R_avg_SIG_STR_landed                            NaN                    NaN
# R_avg_opp_SIG_STR_att                           NaN                    NaN
# R_avg_opp_SIG_STR_landed                        NaN                    NaN
# R_avg_TOTAL_STR_att                             NaN                    NaN
# R_avg_TOTAL_STR_landed                          NaN                    NaN
# R_avg_opp_TOTAL_STR_att                         NaN                    NaN
# R_avg_opp_TOTAL_STR_landed                      NaN                    NaN
# R_avg_TD_att                                    NaN                    NaN
# R_avg_TD_landed                                 NaN                    NaN
# R_avg_opp_TD_att                                NaN                    NaN
# R_avg_opp_TD_landed                             NaN                    NaN
# R_avg_HEAD_att                                  NaN                    NaN
# R_avg_HEAD_landed                               NaN                    NaN
# R_avg_opp_HEAD_att                              NaN                    NaN
# R_avg_opp_HEAD_landed                           NaN                    NaN
# R_avg_BODY_att                                  NaN                    NaN
# R_avg_BODY_landed                               NaN                    NaN
# R_avg_opp_BODY_att                              NaN                    NaN
# R_avg_opp_BODY_landed                           NaN                    NaN
# R_avg_LEG_att                                   NaN                    NaN
# R_avg_LEG_landed                                NaN                    NaN
# R_avg_opp_LEG_att                               NaN                    NaN
# R_avg_opp_LEG_landed                            NaN                    NaN
# R_avg_DISTANCE_att                              NaN                    NaN
# R_avg_DISTANCE_landed                           NaN                    NaN
# R_avg_opp_DISTANCE_att                          NaN                    NaN
# R_avg_opp_DISTANCE_landed                       NaN                    NaN
# R_avg_CLINCH_att                                NaN                    NaN
# R_avg_CLINCH_landed                             NaN                    NaN
# R_avg_opp_CLINCH_att                            NaN                    NaN
# R_avg_opp_CLINCH_landed                         NaN                    NaN
# R_avg_GROUND_att                                NaN                    NaN
# R_avg_GROUND_landed                             NaN                    NaN
# R_avg_opp_GROUND_att                            NaN                    NaN
# R_avg_opp_GROUND_landed                         NaN                    NaN
# R_avg_CTRL_time(seconds)                        NaN                    NaN
# R_avg_opp_CTRL_time(seconds)                    NaN                    NaN
# R_total_time_fought(seconds)                    NaN                    NaN
# R_total_rounds_fought                             0                      0
# R_total_title_bouts                               0                      0
# R_current_win_streak                              0                      0
# R_current_lose_streak                             0                      0
# R_longest_win_streak                              0                      0
# R_wins                                            0                      0
# R_losses                                          0                      0
# R_draw                                            0                      0
# R_win_by_Decision_Majority                        0                      0
# R_win_by_Decision_Split                           0                      0
# R_win_by_Decision_Unanimous                       0                      0
# R_win_by_KO/TKO                                   0                      0
# R_win_by_Submission                               0                      0
# R_win_by_TKO_Doctor_Stoppage                      0                      0
# R_Stance                                   Orthodox                    NaN
# R_SLpM                                          0.0                    0.0
# R_Str_Acc                                       0.0                    0.0
# R_SApM                                          0.0                    0.0
# R_Str_Def                                       0.0                    0.0
# R_TD_Avg                                        0.0                    0.0
# R_TD_Acc                                        0.0                    0.0
# R_TD_Def                                        0.0                    0.0
# R_Sub_Avg                                       0.0                    0.0
# R_Height_cms                                 187.96                    NaN
# R_Reach_cms                                     NaN                    NaN
# R_Weight_lbs                                  225.0                    NaN
# B_age                                           NaN                    NaN
# R_age                                          30.0                    NaN
#
#                                                8046
# R_fighter                              Scott Morris
# B_fighter                            Sean Daugherty
# Referee                               John McCarthy
# date                                     1994-03-11
# location                      Denver, Colorado, USA
# Winner                                          Red
# title_bout                                    False
# weight_class                            Open Weight
# no_of_rounds                                      1
# B_avg_KD                                        NaN
# B_avg_opp_KD                                    NaN
# B_avg_SIG_STR_pct                               NaN
# B_avg_opp_SIG_STR_pct                           NaN
# B_avg_TD_pct                                    NaN
# B_avg_opp_TD_pct                                NaN
# B_avg_SUB_ATT                                   NaN
# B_avg_opp_SUB_ATT                               NaN
# B_avg_REV                                       NaN
# B_avg_opp_REV                                   NaN
# B_avg_SIG_STR_att                               NaN
# B_avg_SIG_STR_landed                            NaN
# B_avg_opp_SIG_STR_att                           NaN
# B_avg_opp_SIG_STR_landed                        NaN
# B_avg_TOTAL_STR_att                             NaN
# B_avg_TOTAL_STR_landed                          NaN
# B_avg_opp_TOTAL_STR_att                         NaN
# B_avg_opp_TOTAL_STR_landed                      NaN
# B_avg_TD_att                                    NaN
# B_avg_TD_landed                                 NaN
# B_avg_opp_TD_att                                NaN
# B_avg_opp_TD_landed                             NaN
# B_avg_HEAD_att                                  NaN
# B_avg_HEAD_landed                               NaN
# B_avg_opp_HEAD_att                              NaN
# B_avg_opp_HEAD_landed                           NaN
# B_avg_BODY_att                                  NaN
# B_avg_BODY_landed                               NaN
# B_avg_opp_BODY_att                              NaN
# B_avg_opp_BODY_landed                           NaN
# B_avg_LEG_att                                   NaN
# B_avg_LEG_landed                                NaN
# B_avg_opp_LEG_att                               NaN
# B_avg_opp_LEG_landed                            NaN
# B_avg_DISTANCE_att                              NaN
# B_avg_DISTANCE_landed                           NaN
# B_avg_opp_DISTANCE_att                          NaN
# B_avg_opp_DISTANCE_landed                       NaN
# B_avg_CLINCH_att                                NaN
# B_avg_CLINCH_landed                             NaN
# B_avg_opp_CLINCH_att                            NaN
# B_avg_opp_CLINCH_landed                         NaN
# B_avg_GROUND_att                                NaN
# B_avg_GROUND_landed                             NaN
# B_avg_opp_GROUND_att                            NaN
# B_avg_opp_GROUND_landed                         NaN
# B_avg_CTRL_time(seconds)                        NaN
# B_avg_opp_CTRL_time(seconds)                    NaN
# B_total_time_fought(seconds)                    NaN
# B_total_rounds_fought                             0
# B_total_title_bouts                               0
# B_current_win_streak                              0
# B_current_lose_streak                             0
# B_longest_win_streak                              0
# B_wins                                            0
# B_losses                                          0
# B_draw                                            0
# B_win_by_Decision_Majority                        0
# B_win_by_Decision_Split                           0
# B_win_by_Decision_Unanimous                       0
# B_win_by_KO/TKO                                   0
# B_win_by_Submission                               0
# B_win_by_TKO_Doctor_Stoppage                      0
# B_Stance                                        NaN
# B_SLpM                                          0.0
# B_Str_Acc                                       0.0
# B_SApM                                          0.0
# B_Str_Def                                       0.0
# B_TD_Avg                                        0.0
# B_TD_Acc                                        0.0
# B_TD_Def                                        0.0
# B_Sub_Avg                                       0.0
# B_Height_cms                                 182.88
# B_Reach_cms                                     NaN
# B_Weight_lbs                                  175.0
# R_avg_KD                                        NaN
# R_avg_opp_KD                                    NaN
# R_avg_SIG_STR_pct                               NaN
# R_avg_opp_SIG_STR_pct                           NaN
# R_avg_TD_pct                                    NaN
# R_avg_opp_TD_pct                                NaN
# R_avg_SUB_ATT                                   NaN
# R_avg_opp_SUB_ATT                               NaN
# R_avg_REV                                       NaN
# R_avg_opp_REV                                   NaN
# R_avg_SIG_STR_att                               NaN
# R_avg_SIG_STR_landed                            NaN
# R_avg_opp_SIG_STR_att                           NaN
# R_avg_opp_SIG_STR_landed                        NaN
# R_avg_TOTAL_STR_att                             NaN
# R_avg_TOTAL_STR_landed                          NaN
# R_avg_opp_TOTAL_STR_att                         NaN
# R_avg_opp_TOTAL_STR_landed                      NaN
# R_avg_TD_att                                    NaN
# R_avg_TD_landed                                 NaN
# R_avg_opp_TD_att                                NaN
# R_avg_opp_TD_landed                             NaN
# R_avg_HEAD_att                                  NaN
# R_avg_HEAD_landed                               NaN
# R_avg_opp_HEAD_att                              NaN
# R_avg_opp_HEAD_landed                           NaN
# R_avg_BODY_att                                  NaN
# R_avg_BODY_landed                               NaN
# R_avg_opp_BODY_att                              NaN
# R_avg_opp_BODY_landed                           NaN
# R_avg_LEG_att                                   NaN
# R_avg_LEG_landed                                NaN
# R_avg_opp_LEG_att                               NaN
# R_avg_opp_LEG_landed                            NaN
# R_avg_DISTANCE_att                              NaN
# R_avg_DISTANCE_landed                           NaN
# R_avg_opp_DISTANCE_att                          NaN
# R_avg_opp_DISTANCE_landed                       NaN
# R_avg_CLINCH_att                                NaN
# R_avg_CLINCH_landed                             NaN
# R_avg_opp_CLINCH_att                            NaN
# R_avg_opp_CLINCH_landed                         NaN
# R_avg_GROUND_att                                NaN
# R_avg_GROUND_landed                             NaN
# R_avg_opp_GROUND_att                            NaN
# R_avg_opp_GROUND_landed                         NaN
# R_avg_CTRL_time(seconds)                        NaN
# R_avg_opp_CTRL_time(seconds)                    NaN
# R_total_time_fought(seconds)                    NaN
# R_total_rounds_fought                             0
# R_total_title_bouts                               0
# R_current_win_streak                              0
# R_current_lose_streak                             0
# R_longest_win_streak                              0
# R_wins                                            0
# R_losses                                          0
# R_draw                                            0
# R_win_by_Decision_Majority                        0
# R_win_by_Decision_Split                           0
# R_win_by_Decision_Unanimous                       0
# R_win_by_KO/TKO                                   0
# R_win_by_Submission                               0
# R_win_by_TKO_Doctor_Stoppage                      0
# R_Stance                                   Orthodox
# R_SLpM                                          0.0
# R_Str_Acc                                       0.0
# R_SApM                                          0.0
# R_Str_Def                                       0.0
# R_TD_Avg                                        0.0
# R_TD_Acc                                        0.0
# R_TD_Def                                        0.0
# R_Sub_Avg                                       0.0
# R_Height_cms                                  177.8
# R_Reach_cms                                     NaN
# R_Weight_lbs                                  210.0
# B_age                                          18.0
# R_age                                           NaN
#
# [161 rows x 8047 columns]

# %%
df.describe()
# Out:
#        no_of_rounds     B_avg_KD  B_avg_opp_KD  B_avg_SIG_STR_pct  \
# count   8047.000000  6342.000000   6342.000000        6342.000000
# mean       3.152106     0.243100      0.177702           0.464121
# std        0.620495     0.368267      0.325411           0.126927
# min        1.000000     0.000000      0.000000           0.000000
# 25%        3.000000     0.000000      0.000000           0.390006
# 50%        3.000000     0.031250      0.000000           0.461149
# 75%        3.000000     0.500000      0.250000           0.539729
# max        5.000000     5.000000      4.000000           1.000000
#
#        B_avg_opp_SIG_STR_pct  B_avg_TD_pct  B_avg_opp_TD_pct  B_avg_SUB_ATT  \
# count            6342.000000   6342.000000       6342.000000    6342.000000
# mean                0.446158      0.279849          0.262150       0.430478
# std                 0.128317      0.266322          0.260167       0.671402
# min                 0.000000      0.000000          0.000000       0.000000
# 25%                 0.367500      0.022090          0.034488       0.000000
# 50%                 0.441250      0.228750          0.196250       0.125000
# 75%                 0.520000      0.475000          0.415000       0.625000
# max                 1.000000      1.000000          1.000000       8.000000
#
#        B_avg_opp_SUB_ATT    B_avg_REV  ...    R_Str_Def     R_TD_Avg  \
# count        6342.000000  6342.000000  ...  8024.000000  8024.000000
# mean            0.371754     0.150633  ...     0.542440     1.581768
# std             0.613837     0.335528  ...     0.092349     1.253058
# min             0.000000     0.000000  ...     0.000000     0.000000
# 25%             0.000000     0.000000  ...     0.510000     0.620000
# 50%             0.062500     0.000000  ...     0.550000     1.310000
# 75%             0.500000     0.125000  ...     0.600000     2.270000
# max             7.000000     6.000000  ...     0.840000    11.110000
#
#           R_TD_Acc     R_TD_Def    R_Sub_Avg  R_Height_cms  R_Reach_cms  \
# count  8024.000000  8024.000000  8024.000000   8020.000000  7625.000000
# mean      0.385890     0.606667     0.629998    178.584170   183.173807
# std       0.183905     0.199858     0.742176      9.032696    10.925494
# min       0.000000     0.000000     0.000000    152.400000   147.320000
# 25%       0.290000     0.500000     0.100000    172.720000   175.260000
# 50%       0.390000     0.630000     0.500000    177.800000   182.880000
# 75%       0.500000     0.740000     0.900000    185.420000   190.500000
# max       1.000000     1.000000    21.900000    210.820000   213.360000
#
#        R_Weight_lbs        B_age        R_age
# count   8022.000000  7875.000000  7961.000000
# mean     168.137123    29.634032    30.034669
# std       36.080710     4.034039     4.240455
# min      115.000000    18.000000    18.000000
# 25%      145.000000    27.000000    27.000000
# 50%      170.000000    29.000000    30.000000
# 75%      185.000000    32.000000    33.000000
# max      345.000000    51.000000    47.000000
#
# [8 rows x 151 columns]

# %% [markdown]
# ## Dealing with NaNs

# %%
for column in df.columns:
    if df[column].isnull().sum()!=0:
        print(f"Nan in {column}: {df[column].isnull().sum()}")
# Out:
# Nan in Referee: 26
# Nan in Winner: 3
# Nan in B_avg_KD: 1705
# Nan in B_avg_opp_KD: 1705
# Nan in B_avg_SIG_STR_pct: 1705
# Nan in B_avg_opp_SIG_STR_pct: 1705
# Nan in B_avg_TD_pct: 1705
# Nan in B_avg_opp_TD_pct: 1705
# Nan in B_avg_SUB_ATT: 1705
# Nan in B_avg_opp_SUB_ATT: 1705
# Nan in B_avg_REV: 1705
# Nan in B_avg_opp_REV: 1705
# Nan in B_avg_SIG_STR_att: 1705
# Nan in B_avg_SIG_STR_landed: 1705
# Nan in B_avg_opp_SIG_STR_att: 1705
# Nan in B_avg_opp_SIG_STR_landed: 1705
# Nan in B_avg_TOTAL_STR_att: 1705
# Nan in B_avg_TOTAL_STR_landed: 1705
# Nan in B_avg_opp_TOTAL_STR_att: 1705
# Nan in B_avg_opp_TOTAL_STR_landed: 1705
# Nan in B_avg_TD_att: 1705
# Nan in B_avg_TD_landed: 1705
# Nan in B_avg_opp_TD_att: 1705
# Nan in B_avg_opp_TD_landed: 1705
# Nan in B_avg_HEAD_att: 1705
# Nan in B_avg_HEAD_landed: 1705
# Nan in B_avg_opp_HEAD_att: 1705
# Nan in B_avg_opp_HEAD_landed: 1705
# Nan in B_avg_BODY_att: 1705
# Nan in B_avg_BODY_landed: 1705
# Nan in B_avg_opp_BODY_att: 1705
# Nan in B_avg_opp_BODY_landed: 1705
# Nan in B_avg_LEG_att: 1705
# Nan in B_avg_LEG_landed: 1705
# Nan in B_avg_opp_LEG_att: 1705
# Nan in B_avg_opp_LEG_landed: 1705
# Nan in B_avg_DISTANCE_att: 1705
# Nan in B_avg_DISTANCE_landed: 1705
# Nan in B_avg_opp_DISTANCE_att: 1705
# Nan in B_avg_opp_DISTANCE_landed: 1705
# Nan in B_avg_CLINCH_att: 1705
# Nan in B_avg_CLINCH_landed: 1705
# Nan in B_avg_opp_CLINCH_att: 1705
# Nan in B_avg_opp_CLINCH_landed: 1705
# Nan in B_avg_GROUND_att: 1705
# Nan in B_avg_GROUND_landed: 1705
# Nan in B_avg_opp_GROUND_att: 1705
# Nan in B_avg_opp_GROUND_landed: 1705
# Nan in B_avg_CTRL_time(seconds): 1705
# Nan in B_avg_opp_CTRL_time(seconds): 1705
# Nan in B_total_time_fought(seconds): 1705
# Nan in B_Stance: 55
# Nan in B_Height_cms: 10
# Nan in B_Reach_cms: 880
# Nan in B_Weight_lbs: 8
# Nan in R_avg_KD: 857
# Nan in R_avg_opp_KD: 857
# Nan in R_avg_SIG_STR_pct: 857
# Nan in R_avg_opp_SIG_STR_pct: 857
# Nan in R_avg_TD_pct: 857
# Nan in R_avg_opp_TD_pct: 857
# Nan in R_avg_SUB_ATT: 857
# Nan in R_avg_opp_SUB_ATT: 857
# Nan in R_avg_REV: 857
# Nan in R_avg_opp_REV: 857
# Nan in R_avg_SIG_STR_att: 857
# Nan in R_avg_SIG_STR_landed: 857
# Nan in R_avg_opp_SIG_STR_att: 857
# Nan in R_avg_opp_SIG_STR_landed: 857
# Nan in R_avg_TOTAL_STR_att: 857
# Nan in R_avg_TOTAL_STR_landed: 857
# Nan in R_avg_opp_TOTAL_STR_att: 857
# Nan in R_avg_opp_TOTAL_STR_landed: 857
# Nan in R_avg_TD_att: 857
# Nan in R_avg_TD_landed: 857
# Nan in R_avg_opp_TD_att: 857
# Nan in R_avg_opp_TD_landed: 857
# Nan in R_avg_HEAD_att: 857
# Nan in R_avg_HEAD_landed: 857
# Nan in R_avg_opp_HEAD_att: 857
# Nan in R_avg_opp_HEAD_landed: 857
# Nan in R_avg_BODY_att: 857
# Nan in R_avg_BODY_landed: 857
# Nan in R_avg_opp_BODY_att: 857
# Nan in R_avg_opp_BODY_landed: 857
# Nan in R_avg_LEG_att: 857
# Nan in R_avg_LEG_landed: 857
# Nan in R_avg_opp_LEG_att: 857
# Nan in R_avg_opp_LEG_landed: 857
# Nan in R_avg_DISTANCE_att: 857
# Nan in R_avg_DISTANCE_landed: 857
# Nan in R_avg_opp_DISTANCE_att: 857
# Nan in R_avg_opp_DISTANCE_landed: 857
# Nan in R_avg_CLINCH_att: 857
# Nan in R_avg_CLINCH_landed: 857
# Nan in R_avg_opp_CLINCH_att: 857
# Nan in R_avg_opp_CLINCH_landed: 857
# Nan in R_avg_GROUND_att: 857
# Nan in R_avg_GROUND_landed: 857
# Nan in R_avg_opp_GROUND_att: 857
# Nan in R_avg_opp_GROUND_landed: 857
# Nan in R_avg_CTRL_time(seconds): 857
# Nan in R_avg_opp_CTRL_time(seconds): 857
# Nan in R_total_time_fought(seconds): 857
# Nan in R_Stance: 44
# Nan in R_SLpM: 23
# Nan in R_Str_Acc: 23
# Nan in R_SApM: 23
# Nan in R_Str_Def: 23
# Nan in R_TD_Avg: 23
# Nan in R_TD_Acc: 23
# Nan in R_TD_Def: 23
# Nan in R_Sub_Avg: 23
# Nan in R_Height_cms: 27
# Nan in R_Reach_cms: 422
# Nan in R_Weight_lbs: 25
# Nan in B_age: 172
# Nan in R_age: 86

# %% [markdown]
# * Looks like the blue fighter stats have 1387 missing rows and the red fighter stats have 704 missing rows, i.e those fighters must not have had any previous fights. We should replace these values with the median.

# %%
df2 = df.copy()

# %% [markdown]
# * Referee doesn't look like an important column. Let's delete that.
# * Let's see if height and reach have a correlation
# * The rest i.e. Age, Stance and Height, let's fill with the median of that column.

# %%
df2.drop(columns=['Referee'], inplace=True)

# %%
df2['R_Reach_cms']
# Out:
# 0       177.80
# 1       165.10
# 2       195.58
# 3       165.10
# 4       200.66
#          ...
# 8042       NaN
# 8043       NaN
# 8044       NaN
# 8045       NaN
# 8046       NaN
# Name: R_Reach_cms, Length: 8047, dtype: float64

# %%
# Set style of scatterplot
sns.set_context("notebook", font_scale=1.1)
sns.set_style("ticks")

# Create scatterplot of dataframe
sns.lmplot(y ='R_Height_cms', # Horizontal axis
           x ='R_Reach_cms', # Vertical axis
           data=df2, # Data source
           fit_reg=True # fix a regression line
           ) # S marker size

# %% [markdown]
# * We can see there is a positive correlation between height and reach. So we'll replace reach with height

# %%
# df2['R_Reach_cms'].fillna(df2['R_Height_cms'], inplace=True)
df2.fillna({'R_Reach_cms': df2['R_Height_cms']}, inplace=True)
# df2['B_Reach_cms'].fillna(df2['B_Height_cms'], inplace=True)
df2.fillna({'B_Reach_cms': df2['B_Height_cms']}, inplace=True)
df2.fillna(df2.select_dtypes(include=['number']).median(), inplace=True)

# %%
df2['B_Stance'].value_counts()
# Out:
# B_Stance
# Orthodox       5999
# Southpaw       1533
# Switch          447
# Open Stance       9
# Sideways          4
# Name: count, dtype: int64

# %%
df2['R_Stance'].value_counts()
# Out:
# R_Stance
# Orthodox       5975
# Southpaw       1592
# Switch          419
# Open Stance      15
# Sideways          2
# Name: count, dtype: int64

# %%
df2['R_Stance'].fillna('Orthodox', inplace=True)
df2['B_Stance'].fillna('Orthodox', inplace=True)
# Out:
# C:\Users\JT\AppData\Local\Temp\ipykernel_18212\876924152.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['R_Stance'].fillna('Orthodox', inplace=True)
# C:\Users\JT\AppData\Local\Temp\ipykernel_18212\876924152.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['B_Stance'].fillna('Orthodox', inplace=True)

# %%
for column in df2.columns:
    if df2[column].isnull().sum()!=0:
        print(f"Nan in {column}: {df2[column].isnull().sum()}")
# Out:
# Nan in Winner: 3

# %% [markdown]
# ## Removing non essential columns

# %%
df2['location'].value_counts()
# Out:
# location
# Las Vegas, Nevada, USA                         2731
# Abu Dhabi, Abu Dhabi, United Arab Emirates      222
# London, England, United Kingdom                 170
# Newark, New Jersey, USA                         114
# Houston, Texas, USA                             108
# Anaheim, California, USA                        107
# New York City, New York, USA                     99
# Atlantic City, New Jersey, USA                   93
# Toronto, Ontario, Canada                         86
# Boston, Massachusetts, USA                       84
# Montreal, Quebec, Canada                         81
# Chicago, Illinois, USA                           81
# Sydney, New South Wales, Australia               80
# Los Angeles, California, USA                     79
# Denver, Colorado, USA                            78
# Rio de Janeiro, Rio de Janeiro, Brazil           78
# Dallas, Texas, USA                               76
# Sao Paulo, Sao Paulo, Brazil                     73
# Stockholm, Sweden                                72
# Nashville, Tennessee, USA                        71
# Mexico City, Distrito Federal, Mexico            71
# Jacksonville, Florida, USA                       70
# Rio de Janeiro, Brazil                           69
# Vancouver, British Columbia, Canada              67
# Sacramento, California, USA                      62
# Kallang, Singapore                               60
# Austin, Texas, USA                               59
# Manchester, England, United Kingdom              58
# Orlando, Florida, USA                            52
# Charlotte, North Carolina, USA                   50
# Phoenix, Arizona, USA                            50
# Melbourne, Victoria, Australia                   48
# Tampa, Florida, USA                              48
# Seattle, Washington, USA                         47
# San Jose, California, USA                        47
# Salt Lake City, Utah, USA                        47
# Atlanta, Georgia, USA                            45
# Saitama, Japan                                   45
# New Orleans, Louisiana, USA                      45
# San Diego, California, USA                       44
# Columbus, Ohio, USA                              41
# Macau, China                                     40
# Perth, Western Australia, Australia              37
# Paris, Ile-de-France, France                     37
# Fortaleza, Ceara, Brazil                         37
# Milwaukee, Wisconsin, USA                        36
# Brasilia, Distrito Federal, Brazil               36
# Edmonton, Alberta, Canada                        35
# Hollywood, Florida, USA                          35
# Philadelphia, Pennsylvania, USA                  35
# Pittsburgh, Pennsylvania, USA                    34
# Miami, Florida, USA                              34
# San Antonio, Texas, USA                          34
# Broomfield, Colorado, USA                        33
# Fairfax, Virginia, USA                           33
# Auckland, New Zealand                            33
# Minneapolis, Minnesota, USA                      32
# Brooklyn, New York, USA                          32
# Uncasville, Connecticut, USA                     32
# Birmingham, Alabama, USA                         31
# Dublin, Leinster, Ireland                        30
# Sao Paulo, Brazil                                30
# Glendale, Arizona, USA                           28
# Kansas City, Missouri, USA                       27
# Louisville, Kentucky, USA                        25
# Norfolk, Virginia, USA                           25
# Jaragua do Sul, Santa Catarina, Brazil           25
# Sunrise, Florida, USA                            25
# Rotterdam, Zuid-Holland, Netherlands             25
# Moscow, Moscow, Russia                           25
# Ottawa, Ontario, Canada                          25
# Hamburg, Hamburg, Germany                        24
# Adelaide, South Australia, Australia             24
# Calgary, Alberta, Canada                         24
# Glasgow, Scotland, United Kingdom                24
# Portland, Oregon, USA                            23
# Brisbane, Queensland, Australia                  23
# St. Louis, Missouri, USA                         23
# Oklahoma City, Oklahoma, USA                     23
# Halifax, Nova Scotia, Canada                     23
# Indianapolis, Indiana, USA                       23
# Goiania, Goias, Brazil                           23
# Washington, DC, USA                              22
# Winnipeg, Manitoba, Canada                       22
# Riyadh, Riyadh, Saudi Arabia                     22
# Barueri, Sao Paulo, Brazil                       22
# Buffalo, New York, USA                           22
# Belo Horizonte, Minas Gerais, Brazil             22
# Cincinnati, Ohio, USA                            22
# Birmingham, England, United Kingdom              21
# Belfast, Northern Ireland, United Kingdom        21
# Detroit, Michigan, USA                           20
# East Rutherford, New Jersey, USA                 20
# Tulsa, Oklahoma, USA                             19
# Omaha, Nebraska, USA                             19
# Abu Dhabi, United Arab Emirates                  18
# Cedar Rapids, Iowa, USA                          16
# Augusta, Georgia, USA                            15
# Lake Charles, Louisiana, USA                     15
# Bay St. Louis, Mississippi, USA                  14
# Wichita, Kansas, USA                             13
# Inglewood, California, USA                       13
# Moncton, New Brunswick, Canada                   13
# Uniondale, New York, USA                         13
# Zagreb, Croatia                                  13
# Santiago, Chile                                  13
# Tokyo, Japan                                     13
# Fresno, California, USA                          13
# Boise, Idaho, USA                                13
# Lincoln, Nebraska, USA                           13
# Busan, South Korea                               13
# Rio Rancho, New Mexico, USA                      13
# Montevideo, Uruguay                              13
# Copenhagen, Denmark                              13
# Fort Campbell, Kentucky, USA                     13
# Prague, Czech Republic                           13
# Rochester, New York, USA                         13
# Monterrey, Nuevo Leon, Mexico                    13
# Quebec City, Quebec, Canada                      13
# Elmont, New York, USA                            12
# Saskatoon, Saskatchewan, Canada                  12
# Curitiba, Parana, Brazil                         12
# Raleigh, North Carolina, USA                     12
# Cologne, North Rhine-Westphalia, Germany         12
# Krakow, Poland                                   12
# Manila, Philippines                              12
# Beijing, China                                   12
# Sioux Falls, South Dakota, USA                   12
# Hidalgo, Texas, USA                              12
# Duluth, Georgia, USA                             12
# Albany, New York, USA                            12
# Shanghai, Hebei, China                           12
# Buenos Aires, Buenos Aires, Argentina            12
# Utica, New York, USA                             12
# Liverpool, England, United Kingdom               11
# Shenzhen, Guangdong, China                       11
# Greenville, South Carolina, USA                  11
# Saint Petersburg, Saint Petersburg, Russia       11
# Berlin, Berlin, Germany                          11
# Seoul, South Korea                               11
# Gdansk, Poland                                   11
# Belem, Para, Brazil                              11
# Killeen, Texas, USA                              11
# Auburn Hills, Michigan, USA                      11
# Natal, Rio Grande do Norte, Brazil               11
# Porto Alegre, Rio Grande do Sul, Brazil          11
# Memphis, Tennessee, USA                          11
# Albuquerque, New Mexico, USA                     11
# Oakland, California, USA                         11
# Nottingham, England, United Kingdom              11
# Cleveland, Ohio, USA                             10
# Saitama, Saitama, Japan                          10
# Uberlandia, Minas Gerais, Brazil                 10
# Baltimore, Maryland, USA                         10
# Fayetteville, North Carolina, USA                10
# Berlin, Germany                                  10
# Bangor, Maine, USA                               10
# Gold Coast, Queensland, Australia                10
# Singapore, Singapore                             10
# Oberhausen, North Rhine-Westphalia, Germany      10
# Rosemont, Illinois, USA                          10
# Ledyard, Connecticut, USA                         9
# Newcastle, England, United Kingdom                9
# Bossier City, Louisiana, USA                      8
# Casper, Wyoming, USA                              8
# Mobile, Alabama, USA                              8
# San Juan, Puerto Rico                             8
# Chiba, Japan                                      7
# Yokohama, Kanagawa, Japan                         7
# Dothan, Alabama, USA                              7
# Name: count, dtype: int64

# %% [markdown]
# * Since we don't have home-country of each fighter, location is useless
# * Date of the fight is also not essential since we already created age with it
# * Draws are incredibly rare and should be removed from the target variable so it becomes a binary classification task
# * Fighter names are also to be removed

# %%
df2['Winner'].value_counts()
# Out:
# Winner
# Red     5122
# Blue    2777
# Draw     145
# Name: count, dtype: int64

# %%
df2.drop(df2.index[df2['Winner'] == 'Draw'], inplace = True)
df2.drop(columns=['location', 'date', 'R_fighter', 'B_fighter'], inplace=True)

# %%
df2.dtypes
# Out:
# Winner                           object
# title_bout                         bool
# weight_class                     object
# no_of_rounds                      int64
# B_avg_KD                        float64
# B_avg_opp_KD                    float64
# B_avg_SIG_STR_pct               float64
# B_avg_opp_SIG_STR_pct           float64
# B_avg_TD_pct                    float64
# B_avg_opp_TD_pct                float64
# B_avg_SUB_ATT                   float64
# B_avg_opp_SUB_ATT               float64
# B_avg_REV                       float64
# B_avg_opp_REV                   float64
# B_avg_SIG_STR_att               float64
# B_avg_SIG_STR_landed            float64
# B_avg_opp_SIG_STR_att           float64
# B_avg_opp_SIG_STR_landed        float64
# B_avg_TOTAL_STR_att             float64
# B_avg_TOTAL_STR_landed          float64
# B_avg_opp_TOTAL_STR_att         float64
# B_avg_opp_TOTAL_STR_landed      float64
# B_avg_TD_att                    float64
# B_avg_TD_landed                 float64
# B_avg_opp_TD_att                float64
# B_avg_opp_TD_landed             float64
# B_avg_HEAD_att                  float64
# B_avg_HEAD_landed               float64
# B_avg_opp_HEAD_att              float64
# B_avg_opp_HEAD_landed           float64
# B_avg_BODY_att                  float64
# B_avg_BODY_landed               float64
# B_avg_opp_BODY_att              float64
# B_avg_opp_BODY_landed           float64
# B_avg_LEG_att                   float64
# B_avg_LEG_landed                float64
# B_avg_opp_LEG_att               float64
# B_avg_opp_LEG_landed            float64
# B_avg_DISTANCE_att              float64
# B_avg_DISTANCE_landed           float64
# B_avg_opp_DISTANCE_att          float64
# B_avg_opp_DISTANCE_landed       float64
# B_avg_CLINCH_att                float64
# B_avg_CLINCH_landed             float64
# B_avg_opp_CLINCH_att            float64
# B_avg_opp_CLINCH_landed         float64
# B_avg_GROUND_att                float64
# B_avg_GROUND_landed             float64
# B_avg_opp_GROUND_att            float64
# B_avg_opp_GROUND_landed         float64
# B_avg_CTRL_time(seconds)        float64
# B_avg_opp_CTRL_time(seconds)    float64
# B_total_time_fought(seconds)    float64
# B_total_rounds_fought             int64
# B_total_title_bouts               int64
# B_current_win_streak              int64
# B_current_lose_streak             int64
# B_longest_win_streak              int64
# B_wins                            int64
# B_losses                          int64
# B_draw                            int64
# B_win_by_Decision_Majority        int64
# B_win_by_Decision_Split           int64
# B_win_by_Decision_Unanimous       int64
# B_win_by_KO/TKO                   int64
# B_win_by_Submission               int64
# B_win_by_TKO_Doctor_Stoppage      int64
# B_Stance                         object
# B_SLpM                          float64
# B_Str_Acc                       float64
# B_SApM                          float64
# B_Str_Def                       float64
# B_TD_Avg                        float64
# B_TD_Acc                        float64
# B_TD_Def                        float64
# B_Sub_Avg                       float64
# B_Height_cms                    float64
# B_Reach_cms                     float64
# B_Weight_lbs                    float64
# R_avg_KD                        float64
# R_avg_opp_KD                    float64
# R_avg_SIG_STR_pct               float64
# R_avg_opp_SIG_STR_pct           float64
# R_avg_TD_pct                    float64
# R_avg_opp_TD_pct                float64
# R_avg_SUB_ATT                   float64
# R_avg_opp_SUB_ATT               float64
# R_avg_REV                       float64
# R_avg_opp_REV                   float64
# R_avg_SIG_STR_att               float64
# R_avg_SIG_STR_landed            float64
# R_avg_opp_SIG_STR_att           float64
# R_avg_opp_SIG_STR_landed        float64
# R_avg_TOTAL_STR_att             float64
# R_avg_TOTAL_STR_landed          float64
# R_avg_opp_TOTAL_STR_att         float64
# R_avg_opp_TOTAL_STR_landed      float64
# R_avg_TD_att                    float64
# R_avg_TD_landed                 float64
# R_avg_opp_TD_att                float64
# R_avg_opp_TD_landed             float64
# R_avg_HEAD_att                  float64
# R_avg_HEAD_landed               float64
# R_avg_opp_HEAD_att              float64
# R_avg_opp_HEAD_landed           float64
# R_avg_BODY_att                  float64
# R_avg_BODY_landed               float64
# R_avg_opp_BODY_att              float64
# R_avg_opp_BODY_landed           float64
# R_avg_LEG_att                   float64
# R_avg_LEG_landed                float64
# R_avg_opp_LEG_att               float64
# R_avg_opp_LEG_landed            float64
# R_avg_DISTANCE_att              float64
# R_avg_DISTANCE_landed           float64
# R_avg_opp_DISTANCE_att          float64
# R_avg_opp_DISTANCE_landed       float64
# R_avg_CLINCH_att                float64
# R_avg_CLINCH_landed             float64
# R_avg_opp_CLINCH_att            float64
# R_avg_opp_CLINCH_landed         float64
# R_avg_GROUND_att                float64
# R_avg_GROUND_landed             float64
# R_avg_opp_GROUND_att            float64
# R_avg_opp_GROUND_landed         float64
# R_avg_CTRL_time(seconds)        float64
# R_avg_opp_CTRL_time(seconds)    float64
# R_total_time_fought(seconds)    float64
# R_total_rounds_fought             int64
# R_total_title_bouts               int64
# R_current_win_streak              int64
# R_current_lose_streak             int64
# R_longest_win_streak              int64
# R_wins                            int64
# R_losses                          int64
# R_draw                            int64
# R_win_by_Decision_Majority        int64
# R_win_by_Decision_Split           int64
# R_win_by_Decision_Unanimous       int64
# R_win_by_KO/TKO                   int64
# R_win_by_Submission               int64
# R_win_by_TKO_Doctor_Stoppage      int64
# R_Stance                         object
# R_SLpM                          float64
# R_Str_Acc                       float64
# R_SApM                          float64
# R_Str_Def                       float64
# R_TD_Avg                        float64
# R_TD_Acc                        float64
# R_TD_Def                        float64
# R_Sub_Avg                       float64
# R_Height_cms                    float64
# R_Reach_cms                     float64
# R_Weight_lbs                    float64
# B_age                           float64
# R_age                           float64
# dtype: object

# %% [markdown]
# * Weight class and Stance are categories, Winner is out target variable.
# * We can one hot encode the categories

# %%
df2 = pd.concat([df2, pd.get_dummies(df2[['weight_class', 'B_Stance', 'R_Stance']])], axis=1)
df2.drop(columns=['weight_class', 'B_Stance', 'R_Stance'], inplace=True)

# %%
df2
# Out:
#      Winner  title_bout  no_of_rounds  B_avg_KD  B_avg_opp_KD  \
# 0       Red       False             3  0.140625      0.003906
# 1       Red       False             3  0.000000      0.000000
# 2      Blue       False             3  1.265625      0.000000
# 3       Red       False             3  0.000000      0.000000
# 4      Blue        True             5  0.262573      0.015625
# ...     ...         ...           ...       ...           ...
# 8042    Red       False             1  0.031250      0.000000
# 8043    Red       False             1  0.031250      0.000000
# 8044    Red       False             1  0.031250      0.000000
# 8045    Red       False             1  0.031250      0.000000
# 8046    Red       False             1  0.031250      0.000000
#
#       B_avg_SIG_STR_pct  B_avg_opp_SIG_STR_pct  B_avg_TD_pct  \
# 0              0.540078               0.474609      0.007812
# 1              0.458750               0.344375      0.632500
# 2              0.510781               0.434844      0.000000
# 3              0.530000               0.500000      0.370000
# 4              0.553444               0.429452      0.148796
# ...                 ...                    ...           ...
# 8042           0.461149               0.441250      0.228750
# 8043           0.461149               0.441250      0.228750
# 8044           0.461149               0.441250      0.228750
# 8045           0.461149               0.441250      0.228750
# 8046           0.461149               0.441250      0.228750
#
#       B_avg_opp_TD_pct  B_avg_SUB_ATT  ...  B_Stance_Open Stance  \
# 0             0.193125         0.0000  ...                 False
# 1             0.541250         0.1250  ...                 False
# 2             0.082812         0.0625  ...                 False
# 3             0.500000         0.0000  ...                 False
# 4             0.000659         0.0000  ...                 False
# ...                ...            ...  ...                   ...
# 8042          0.196250         0.1250  ...                 False
# 8043          0.196250         0.1250  ...                 False
# 8044          0.196250         0.1250  ...                 False
# 8045          0.196250         0.1250  ...                 False
# 8046          0.196250         0.1250  ...                 False
#
#       B_Stance_Orthodox  B_Stance_Sideways  B_Stance_Southpaw  \
# 0                 False              False              False
# 1                  True              False              False
# 2                  True              False              False
# 3                  True              False              False
# 4                  True              False              False
# ...                 ...                ...                ...
# 8042               True              False              False
# 8043               True              False              False
# 8044               True              False              False
# 8045               True              False              False
# 8046               True              False              False
#
#       B_Stance_Switch  R_Stance_Open Stance  R_Stance_Orthodox  \
# 0                True                 False               True
# 1               False                 False              False
# 2               False                 False              False
# 3               False                 False               True
# 4               False                 False               True
# ...               ...                   ...                ...
# 8042            False                 False              False
# 8043            False                 False               True
# 8044            False                 False               True
# 8045            False                 False               True
# 8046            False                 False               True
#
#       R_Stance_Sideways  R_Stance_Southpaw  R_Stance_Switch
# 0                 False              False            False
# 1                 False               True            False
# 2                 False               True            False
# 3                 False              False            False
# 4                 False              False            False
# ...                 ...                ...              ...
# 8042              False               True            False
# 8043              False              False            False
# 8044              False              False            False
# 8045              False              False            False
# 8046              False              False            False
#
# [7902 rows x 177 columns]

# %% [markdown]
# ## Saving the data

# %%
df2.to_csv('../data/preprocessed_data.csv', index=False)
